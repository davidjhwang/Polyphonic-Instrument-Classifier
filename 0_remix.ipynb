# %%
import os
import yaml
from pydub import AudioSegment

# Define target folder and instrument IDs to remove
DIR_PATH = "slakh2100_flac_redux/reduced_train"

# %%
import time

program_nums_to_remove = {6, 7, 46, 47, 52, 53, 54, 55, 69, 70, 76, 77, 78, 79}

# Iterate through each track folder
for track in os.listdir(DIR_PATH):
    track_path = os.path.join(DIR_PATH, track)
    metadata_path = os.path.join(track_path, "metadata.yaml")
    stems_path = os.path.join(track_path, "stems")
    mix_path = os.path.join(track_path, "mix.flac")
    
    if not os.path.isdir(track_path) or not os.path.exists(metadata_path):
        continue  
    
    print(f"Processing track: {track}")  # Debugging print
    
    with open(metadata_path, "r") as f:
        metadata = yaml.safe_load(f)
    
    if "stems" not in metadata:
        continue  
    
    stems_to_remove = []
    for stem_id, stem_data in metadata["stems"].items():
        # Check if the instrument class is in the list of ones to remove
        inst_class = stem_data.get("inst_class", "")
        program_num = stem_data.get("program_num", None)
        
        # Add to removal list if inst_class is in the excluded list or if program_num is in the specified set
        if inst_class in {"Chromatic Percussion", "Organ", "Synth Lead", "Synth Pad", "Sound Effects", "Ethnic", "Percussive", "Sound effects", "Brass", "Reed", "Pipe"} or program_num in program_nums_to_remove:
            stems_to_remove.append(stem_id)
    
    print(f"Stems to remove: {stems_to_remove}")  # Debugging print

    # If no stems to remove, skip processing this track
    if not stems_to_remove:
        print(f"No stems removed for {track}. Skipping mix update.")  # Debugging print
        continue  

    for stem_id in stems_to_remove:
        stem_file = os.path.join(stems_path, f"{stem_id}.flac")
        if os.path.exists(stem_file):
            print(f"Removing {stem_file}")  # Debugging print
            os.remove(stem_file)
        del metadata["stems"][stem_id]  
    
    with open(metadata_path, "w") as f:
        yaml.dump(metadata, f, default_flow_style=False)
    
    remaining_stems = [os.path.join(stems_path, f"{stem_id}.flac") for stem_id in metadata["stems"] if os.path.exists(os.path.join(stems_path, f"{stem_id}.flac"))]
    print(f"Remaining stems: {remaining_stems}")  # Debugging print
    
    if remaining_stems:
        mixed_audio = None
        for stem_file in remaining_stems:
            print(f"Mixing {stem_file}")  # Debugging print
            audio = AudioSegment.from_file(stem_file)
            mixed_audio = audio if mixed_audio is None else mixed_audio.overlay(audio)
        print("Exporting mixed file")  # Debugging print
        mixed_audio.export(mix_path, format="flac")
    else:
        print(f"Deleting track folder: {track_path}")  # Debugging print
        for root, dirs, files in os.walk(track_path, topdown=False):
            for file in files:
                file_path = os.path.join(root, file)
                print(f"Deleting file: {file_path}")  # Debugging print
                os.remove(file_path)
            for dir in dirs:
                dir_path = os.path.join(root, dir)
                print(f"Deleting dir: {dir_path}")  # Debugging print
                os.rmdir(dir_path)
        print(f"Removing empty track folder: {track_path}")  # Debugging print
        os.rmdir(track_path)

    print(f"Finished processing track: {track}")  # Debugging print
    time.sleep(0.1)  # Prevent excessive CPU usage
# Out:
# Processing track: Track00001
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00001\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00001\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00001\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00001\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00001\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00001\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00001\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00001\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00001\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00001\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00001\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00001\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00001\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00001
# Processing track: Track00002
# Stems to remove: ['S04', 'S06', 'S11']
# Removing slakh2100_flac_redux/reduced_train\Track00002\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track00002\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00002
# Processing track: Track00003
# Stems to remove: []
# No stems removed for Track00003. Skipping mix update.
# Processing track: Track00004
# Stems to remove: ['S02', 'S06']
# Removing slakh2100_flac_redux/reduced_train\Track00004\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_train\Track00004\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00004\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00004\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00004\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00004\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00004\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00004\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00004\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00004\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00004\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00004\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00004
# Processing track: Track00005
# Stems to remove: []
# No stems removed for Track00005. Skipping mix update.
# Processing track: Track00006
# Stems to remove: []
# No stems removed for Track00006. Skipping mix update.
# Processing track: Track00007
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00007\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00007
# Processing track: Track00008
# Stems to remove: []
# No stems removed for Track00008. Skipping mix update.
# Processing track: Track00009
# Stems to remove: ['S04', 'S11']
# Removing slakh2100_flac_redux/reduced_train\Track00009\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track00009\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00009\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00009\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00009\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00009\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00009\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00009\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00009\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00009\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00009\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00009\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00009
# Processing track: Track00010
# Stems to remove: []
# No stems removed for Track00010. Skipping mix update.
# Processing track: Track00011
# Stems to remove: []
# No stems removed for Track00011. Skipping mix update.
# Processing track: Track00012
# Stems to remove: ['S07', 'S09']
# Removing slakh2100_flac_redux/reduced_train\Track00012\stems\S07.flac
# Removing slakh2100_flac_redux/reduced_train\Track00012\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00012
# Processing track: Track00013
# Stems to remove: []
# No stems removed for Track00013. Skipping mix update.
# Processing track: Track00014
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00014\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00014
# Processing track: Track00015
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00015\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00015\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00015\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00015\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00015\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00015\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00015\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00015\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00015\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00015\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00015\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track00015
# Processing track: Track00016
# Stems to remove: ['S11', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track00016\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S15.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S15.flac
# Exporting mixed file
# Finished processing track: Track00016
# Processing track: Track00017
# Stems to remove: ['S07', 'S10']
# Removing slakh2100_flac_redux/reduced_train\Track00017\stems\S07.flac
# Removing slakh2100_flac_redux/reduced_train\Track00017\stems\S10.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00017\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00017\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00017\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00017\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00017\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00017\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00017\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00017\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00017\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00017\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00017\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00017\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00017\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00017\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00017
# Processing track: Track00018
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00018\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S14.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S15.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S16.flac', 'slakh2100_flac_redux/reduced_train\\Track00018\\stems\\S17.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S14.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S15.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S16.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00018\stems\S17.flac
# Exporting mixed file
# Finished processing track: Track00018
# Processing track: Track00019
# Stems to remove: ['S11']
# Removing slakh2100_flac_redux/reduced_train\Track00019\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00019
# Processing track: Track00020
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00020\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00020
# Processing track: Track00021
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_train\Track00021\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00021
# Processing track: Track00022
# Stems to remove: []
# No stems removed for Track00022. Skipping mix update.
# Processing track: Track00023
# Stems to remove: []
# No stems removed for Track00023. Skipping mix update.
# Processing track: Track00024
# Stems to remove: []
# No stems removed for Track00024. Skipping mix update.
# Processing track: Track00025
# Stems to remove: []
# No stems removed for Track00025. Skipping mix update.
# Processing track: Track00026
# Stems to remove: []
# No stems removed for Track00026. Skipping mix update.
# Processing track: Track00027
# Stems to remove: []
# No stems removed for Track00027. Skipping mix update.
# Processing track: Track00028
# Stems to remove: []
# No stems removed for Track00028. Skipping mix update.
# Processing track: Track00029
# Stems to remove: []
# No stems removed for Track00029. Skipping mix update.
# Processing track: Track00030
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_train\Track00030\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track00030
# Processing track: Track00031
# Stems to remove: []
# No stems removed for Track00031. Skipping mix update.
# Processing track: Track00032
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00032\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00032
# Processing track: Track00033
# Stems to remove: []
# No stems removed for Track00033. Skipping mix update.
# Processing track: Track00034
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00034\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00034
# Processing track: Track00035
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00035\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00035
# Processing track: Track00036
# Stems to remove: []
# No stems removed for Track00036. Skipping mix update.
# Processing track: Track00037
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_train\Track00037\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00037
# Processing track: Track00038
# Stems to remove: []
# No stems removed for Track00038. Skipping mix update.
# Processing track: Track00039
# Stems to remove: []
# No stems removed for Track00039. Skipping mix update.
# Processing track: Track00040
# Stems to remove: []
# No stems removed for Track00040. Skipping mix update.
# Processing track: Track00041
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00041\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00041
# Processing track: Track00042
# Stems to remove: ['S04', 'S08']
# Removing slakh2100_flac_redux/reduced_train\Track00042\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track00042\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00042\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00042\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00042\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00042\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00042\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00042\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00042\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00042\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00042\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00042\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00042\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00042\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00042\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00042\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track00042
# Processing track: Track00043
# Stems to remove: []
# No stems removed for Track00043. Skipping mix update.
# Processing track: Track00044
# Stems to remove: ['S09', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track00044\stems\S09.flac
# Removing slakh2100_flac_redux/reduced_train\Track00044\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track00044
# Processing track: Track00045
# Stems to remove: []
# No stems removed for Track00045. Skipping mix update.
# Processing track: Track00046
# Stems to remove: []
# No stems removed for Track00046. Skipping mix update.
# Processing track: Track00047
# Stems to remove: ['S06', 'S07']
# Removing slakh2100_flac_redux/reduced_train\Track00047\stems\S06.flac
# Removing slakh2100_flac_redux/reduced_train\Track00047\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S04.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S04.flac
# Exporting mixed file
# Finished processing track: Track00047
# Processing track: Track00048
# Stems to remove: ['S06', 'S15', 'S18']
# Removing slakh2100_flac_redux/reduced_train\Track00048\stems\S15.flac
# Removing slakh2100_flac_redux/reduced_train\Track00048\stems\S18.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S16.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S17.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S16.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S17.flac
# Exporting mixed file
# Finished processing track: Track00048
# Processing track: Track00050
# Stems to remove: ['S06', 'S07']
# Removing slakh2100_flac_redux/reduced_train\Track00050\stems\S06.flac
# Removing slakh2100_flac_redux/reduced_train\Track00050\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00050
# Processing track: Track00051
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00051\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track00051
# Processing track: Track00052
# Stems to remove: []
# No stems removed for Track00052. Skipping mix update.
# Processing track: Track00053
# Stems to remove: []
# No stems removed for Track00053. Skipping mix update.
# Processing track: Track00054
# Stems to remove: []
# No stems removed for Track00054. Skipping mix update.
# Processing track: Track00055
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00055\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00055
# Processing track: Track00056
# Stems to remove: ['S11']
# Removing slakh2100_flac_redux/reduced_train\Track00056\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00056
# Processing track: Track00057
# Stems to remove: ['S10']
# Removing slakh2100_flac_redux/reduced_train\Track00057\stems\S10.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00057
# Processing track: Track00058
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_train\Track00058\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00058
# Processing track: Track00059
# Stems to remove: []
# No stems removed for Track00059. Skipping mix update.
# Processing track: Track00060
# Stems to remove: []
# No stems removed for Track00060. Skipping mix update.
# Processing track: Track00061
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00061\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00061
# Processing track: Track00062
# Stems to remove: []
# No stems removed for Track00062. Skipping mix update.
# Processing track: Track00063
# Stems to remove: []
# No stems removed for Track00063. Skipping mix update.
# Processing track: Track00064
# Stems to remove: ['S11']
# Removing slakh2100_flac_redux/reduced_train\Track00064\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00064
# Processing track: Track00065
# Stems to remove: ['S09']
# Removing slakh2100_flac_redux/reduced_train\Track00065\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00065\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00065\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00065\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00065\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00065\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00065\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00065\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00065\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00065\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00065\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00065\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00065\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00065
# Processing track: Track00066
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_train\Track00066\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00066\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00066\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00066
# Processing track: Track00067
# Stems to remove: []
# No stems removed for Track00067. Skipping mix update.
# Processing track: Track00068
# Stems to remove: []
# No stems removed for Track00068. Skipping mix update.
# Processing track: Track00069
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00069\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00069
# Processing track: Track00070
# Stems to remove: ['S01', 'S02']
# Removing slakh2100_flac_redux/reduced_train\Track00070\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_train\Track00070\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00070\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00070\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00070\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00070\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00070\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track00070\\stems\\S17.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00070\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00070\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00070\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00070\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00070\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00070\stems\S17.flac
# Exporting mixed file
# Finished processing track: Track00070
# Processing track: Track00071
# Stems to remove: ['S01', 'S09']
# Removing slakh2100_flac_redux/reduced_train\Track00071\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_train\Track00071\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S14.flac', 'slakh2100_flac_redux/reduced_train\\Track00071\\stems\\S15.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S14.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00071\stems\S15.flac
# Exporting mixed file
# Finished processing track: Track00071
# Processing track: Track00072
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_train\Track00072\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00072\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00072\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00072\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00072\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00072\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00072\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00072\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00072\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00072\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00072\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00072\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00072\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00072
# Processing track: Track00073
# Stems to remove: ['S07', 'S08']
# Removing slakh2100_flac_redux/reduced_train\Track00073\stems\S07.flac
# Removing slakh2100_flac_redux/reduced_train\Track00073\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00073\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00073\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00073\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00073\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00073\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00073\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00073\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00073\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00073\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00073\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track00073
# Processing track: Track00074
# Stems to remove: []
# No stems removed for Track00074. Skipping mix update.
# Processing track: Track00075
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00075\stems\S01.flac
# ...
# Mixing slakh2100_flac_redux/reduced_train\Track01461\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01461\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01461
# Processing track: Track01462
# Stems to remove: []
# No stems removed for Track01462. Skipping mix update.
# Processing track: Track01463
# Stems to remove: []
# No stems removed for Track01463. Skipping mix update.
# Processing track: Track01464
# Stems to remove: ['S04', 'S11']
# Removing slakh2100_flac_redux/reduced_train\Track01464\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track01464\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01464\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01464\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01464\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track01464\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track01464\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01464\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01464\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01464\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01464\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01464\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track01464
# Processing track: Track01465
# Stems to remove: []
# No stems removed for Track01465. Skipping mix update.
# Processing track: Track01466
# Stems to remove: []
# No stems removed for Track01466. Skipping mix update.
# Processing track: Track01468
# Stems to remove: []
# No stems removed for Track01468. Skipping mix update.
# Processing track: Track01471
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track01471\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01471\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01471\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01471\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track01471\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track01471\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track01471\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01471\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01471\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01471\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01471\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01471\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01471\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track01471
# Processing track: Track01473
# Stems to remove: ['S04', 'S11', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track01473\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track01473\stems\S11.flac
# Removing slakh2100_flac_redux/reduced_train\Track01473\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01473\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01473\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track01473\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track01473\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track01473\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track01473\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track01473\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01473\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01473\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01473\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01473\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01473\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01473\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01473\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track01473
# Processing track: Track01474
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track01474\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01474\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01474\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01474\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track01474\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track01474\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01474\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01474\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01474\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01474\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01474\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track01474
# Processing track: Track01475
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track01475\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01475\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track01475\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track01475\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track01475\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track01475\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track01475\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track01475\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01475\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01475\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01475\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01475\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01475\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01475\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01475\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01475
# Processing track: Track01476
# Stems to remove: []
# No stems removed for Track01476. Skipping mix update.
# Processing track: Track01477
# Stems to remove: ['S08', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track01477\stems\S08.flac
# Removing slakh2100_flac_redux/reduced_train\Track01477\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track01477\\stems\\S15.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01477\stems\S15.flac
# Exporting mixed file
# Finished processing track: Track01477
# Processing track: Track01479
# Stems to remove: []
# No stems removed for Track01479. Skipping mix update.
# Processing track: Track01480
# Stems to remove: ['S04', 'S05']
# Removing slakh2100_flac_redux/reduced_train\Track01480\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track01480\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01480\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01480\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01480\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track01480\\stems\\S03.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01480\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01480\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01480\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01480\stems\S03.flac
# Exporting mixed file
# Finished processing track: Track01480
# Processing track: Track01481
# Stems to remove: []
# No stems removed for Track01481. Skipping mix update.
# Processing track: Track01482
# Stems to remove: []
# No stems removed for Track01482. Skipping mix update.
# Processing track: Track01483
# Stems to remove: ['S02', 'S11', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track01483\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_train\Track01483\stems\S11.flac
# Removing slakh2100_flac_redux/reduced_train\Track01483\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01483\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01483\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01483\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track01483\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track01483\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track01483\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track01483\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01483\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01483\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01483\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01483\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01483\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01483\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01483\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track01483
# Processing track: Track01485
# Stems to remove: []
# No stems removed for Track01485. Skipping mix update.
# Processing track: Track01486
# Stems to remove: []
# No stems removed for Track01486. Skipping mix update.
# Processing track: Track01487
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_train\Track01487\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track01487\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01487\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track01487
# Processing track: Track01488
# Stems to remove: []
# No stems removed for Track01488. Skipping mix update.
# Processing track: Track01489
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track01489\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track01489\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01489\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track01489
# Processing track: Track01491
# Stems to remove: ['S04', 'S05', 'S06']
# Removing slakh2100_flac_redux/reduced_train\Track01491\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track01491\stems\S05.flac
# Removing slakh2100_flac_redux/reduced_train\Track01491\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01491\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01491\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track01491\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track01491\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01491\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01491\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01491\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01491\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track01491
# Processing track: Track01492
# Stems to remove: []
# No stems removed for Track01492. Skipping mix update.
# Processing track: Track01494
# Stems to remove: []
# No stems removed for Track01494. Skipping mix update.
# Processing track: Track01495
# Stems to remove: []
# No stems removed for Track01495. Skipping mix update.
# Processing track: Track01496
# Stems to remove: []
# No stems removed for Track01496. Skipping mix update.
# Processing track: Track01497
# Stems to remove: []
# No stems removed for Track01497. Skipping mix update.
# Processing track: Track01500
# Stems to remove: ['S11']
# Removing slakh2100_flac_redux/reduced_train\Track01500\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_train\\Track01500\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_train\Track01500\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track01500
