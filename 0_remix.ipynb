# %%
import os
import yaml
from pydub import AudioSegment

# Define target folder and instrument IDs to remove
DIR_PATH = "slakh2100_flac_redux/reduced_validation"

# %%
import time

program_nums_to_remove = {4, 5, 6, 7, 46, 47, 52, 53, 54, 55, 69, 70, 76, 77, 78, 79}

# Iterate through each track folder
for track in os.listdir(DIR_PATH):
    track_path = os.path.join(DIR_PATH, track)
    metadata_path = os.path.join(track_path, "metadata.yaml")
    stems_path = os.path.join(track_path, "stems")
    mix_path = os.path.join(track_path, "mix.flac")
    
    if not os.path.isdir(track_path) or not os.path.exists(metadata_path):
        continue  
    
    print(f"Processing track: {track}")  # Debugging print
    
    with open(metadata_path, "r") as f:
        metadata = yaml.safe_load(f)
    
    if "stems" not in metadata:
        continue  
    
    stems_to_remove = []
    for stem_id, stem_data in metadata["stems"].items():
        # Check if the instrument class is in the list of ones to remove
        inst_class = stem_data.get("inst_class", "")
        program_num = stem_data.get("program_num", None)
        
        # Add to removal list if inst_class is in the excluded list or if program_num is in the specified set
        if inst_class in {"Chromatic Percussion", "Organ", "Synth Lead", "Synth Pad", "Sound Effects", "Ethnic", "Percussive", "Sound effects", "Brass", "Reed", "Pipe"} or program_num in program_nums_to_remove:
            stems_to_remove.append(stem_id)
    
    print(f"Stems to remove: {stems_to_remove}")  # Debugging print

    # If no stems to remove, skip processing this track
    if not stems_to_remove:
        print(f"No stems removed for {track}. Skipping mix update.")  # Debugging print
        continue  

    for stem_id in stems_to_remove:
        stem_file = os.path.join(stems_path, f"{stem_id}.flac")
        if os.path.exists(stem_file):
            print(f"Removing {stem_file}")  # Debugging print
            os.remove(stem_file)
        del metadata["stems"][stem_id]  
    
    with open(metadata_path, "w") as f:
        yaml.dump(metadata, f, default_flow_style=False)
    
    remaining_stems = [os.path.join(stems_path, f"{stem_id}.flac") for stem_id in metadata["stems"] if os.path.exists(os.path.join(stems_path, f"{stem_id}.flac"))]
    print(f"Remaining stems: {remaining_stems}")  # Debugging print
    
    if remaining_stems:
        mixed_audio = None
        for stem_file in remaining_stems:
            print(f"Mixing {stem_file}")  # Debugging print
            audio = AudioSegment.from_file(stem_file)
            mixed_audio = audio if mixed_audio is None else mixed_audio.overlay(audio)
        print("Exporting mixed file")  # Debugging print
        mixed_audio.export(mix_path, format="flac")
    else:
        print(f"Deleting track folder: {track_path}")  # Debugging print
        for root, dirs, files in os.walk(track_path, topdown=False):
            for file in files:
                file_path = os.path.join(root, file)
                print(f"Deleting file: {file_path}")  # Debugging print
                os.remove(file_path)
            for dir in dirs:
                dir_path = os.path.join(root, dir)
                print(f"Deleting dir: {dir_path}")  # Debugging print
                os.rmdir(dir_path)
        print(f"Removing empty track folder: {track_path}")  # Debugging print
        os.rmdir(track_path)

    print(f"Finished processing track: {track}")  # Debugging print
    time.sleep(0.1)  # Prevent excessive CPU usage
# Out:
# Processing track: Track01501
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_validation\Track01501\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01501\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01501\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01501\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01501\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01501\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01501\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01501\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01501\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01501\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01501\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track01501
# Processing track: Track01502
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_validation\Track01502\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01502\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01502\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track01502
# Processing track: Track01503
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01503\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01503\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01503\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01503\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01503\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01503\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01503\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01503\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01503\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01503\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01503\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track01503
# Processing track: Track01504
# Stems to remove: []
# No stems removed for Track01504. Skipping mix update.
# Processing track: Track01505
# Stems to remove: []
# No stems removed for Track01505. Skipping mix update.
# Processing track: Track01507
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01507\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01507\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01507\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01507\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01507\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01507\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01507\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01507\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01507\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01507\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01507\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track01507
# Processing track: Track01508
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_validation\Track01508\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_validation\\Track01508\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01508\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track01508
# Processing track: Track01509
# Stems to remove: []
# No stems removed for Track01509. Skipping mix update.
# Processing track: Track01510
# Stems to remove: ['S02', 'S04']
# Removing slakh2100_flac_redux/reduced_validation\Track01510\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_validation\Track01510\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01510\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01510\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01510\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01510\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01510\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01510\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01510\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01510\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track01510
# Processing track: Track01511
# Stems to remove: []
# No stems removed for Track01511. Skipping mix update.
# Processing track: Track01512
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_validation\Track01512\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01512\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01512\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track01512
# Processing track: Track01513
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01513\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01513\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01513\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01513\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01513\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01513\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01513\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01513\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01513\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01513\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01513\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01513\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01513\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track01513
# Processing track: Track01514
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01514\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01514\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01514\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01514\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01514\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01514\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01514\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01514\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01514\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01514\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01514\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01514\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01514\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01514\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01514\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track01514
# Processing track: Track01515
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_validation\Track01515\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01515\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01515\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01515\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01515\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01515\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01515\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01515\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01515\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01515\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01515\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01515\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01515\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01515
# Processing track: Track01516
# Stems to remove: []
# No stems removed for Track01516. Skipping mix update.
# Processing track: Track01517
# Stems to remove: []
# No stems removed for Track01517. Skipping mix update.
# Processing track: Track01518
# Stems to remove: ['S12']
# Removing slakh2100_flac_redux/reduced_validation\Track01518\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_validation\\Track01518\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01518\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track01518
# Processing track: Track01519
# Stems to remove: []
# No stems removed for Track01519. Skipping mix update.
# Processing track: Track01520
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_validation\Track01520\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01520\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01520\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01520\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01520\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01520\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01520\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01520\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01520\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01520\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01520\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01520\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01520\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track01520
# Processing track: Track01521
# Stems to remove: ['S01', 'S07']
# Removing slakh2100_flac_redux/reduced_validation\Track01521\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_validation\Track01521\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_validation\\Track01521\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01521\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track01521
# Processing track: Track01522
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_validation\Track01522\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01522\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01522\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01522\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01522\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01522\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01522\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01522\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01522\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01522
# Processing track: Track01523
# Stems to remove: []
# No stems removed for Track01523. Skipping mix update.
# Processing track: Track01524
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_validation\Track01524\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01524\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01524\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01524\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01524\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01524\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01524\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01524\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01524\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01524\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01524\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01524\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01524\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01524\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01524\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01524
# Processing track: Track01525
# Stems to remove: ['S00', 'S01']
# Removing slakh2100_flac_redux/reduced_validation\Track01525\stems\S00.flac
# Removing slakh2100_flac_redux/reduced_validation\Track01525\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01525\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01525\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01525\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01525\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01525\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01525\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01525\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01525\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01525\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01525\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track01525
# Processing track: Track01526
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01526\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01526\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01526\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01526\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01526\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01526\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01526\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01526\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01526\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01526\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01526\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01526\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01526\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01526\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01526\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track01526
# Processing track: Track01527
# Stems to remove: []
# No stems removed for Track01527. Skipping mix update.
# Processing track: Track01528
# Stems to remove: []
# No stems removed for Track01528. Skipping mix update.
# Processing track: Track01529
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01529\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01529\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01529\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01529\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01529\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01529\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01529\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01529\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01529\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01529\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01529\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01529\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01529\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01529\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01529\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track01529
# Processing track: Track01530
# Stems to remove: []
# No stems removed for Track01530. Skipping mix update.
# Processing track: Track01531
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_validation\Track01531\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_validation\\Track01531\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01531\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track01531
# Processing track: Track01532
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01532\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01532\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01532\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01532\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01532\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01532\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01532\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01532\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01532\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01532\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01532\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track01532
# Processing track: Track01533
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_validation\Track01533\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01533\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01533\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01533\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01533\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01533\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01533\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_validation\\Track01533\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01533\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01533\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01533\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01533\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01533\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01533\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01533\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track01533
# Processing track: Track01537
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01537\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01537\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01537\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01537\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01537\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01537\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01537\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01537\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01537\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01537\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01537\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01537\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01537\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01537
# Processing track: Track01539
# Stems to remove: ['S02', 'S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01539\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_validation\Track01539\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01539\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01539\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01539\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01539\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01539\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01539\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01539\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01539\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01539\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01539\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track01539
# Processing track: Track01540
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_validation\Track01540\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01540\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01540\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01540\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01540\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01540\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01540\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01540\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01540\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01540\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01540\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01540
# Processing track: Track01542
# Stems to remove: []
# No stems removed for Track01542. Skipping mix update.
# Processing track: Track01545
# Stems to remove: []
# No stems removed for Track01545. Skipping mix update.
# Processing track: Track01546
# Stems to remove: ['S00', 'S01']
# Removing slakh2100_flac_redux/reduced_validation\Track01546\stems\S00.flac
# Removing slakh2100_flac_redux/reduced_validation\Track01546\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01546\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01546\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01546\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01546\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01546\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01546\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01546\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01546\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01546\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01546\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01546\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01546\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track01546
# Processing track: Track01548
# Stems to remove: []
# No stems removed for Track01548. Skipping mix update.
# Processing track: Track01551
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01551\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01551\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01551\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01551\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01551\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01551\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01551\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01551\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01551\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01551\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01551\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01551\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01551\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01551
# Processing track: Track01552
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_validation\Track01552\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_validation\\Track01552\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01552\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track01552
# Processing track: Track01554
# Stems to remove: []
# No stems removed for Track01554. Skipping mix update.
# Processing track: Track01556
# Stems to remove: []
# No stems removed for Track01556. Skipping mix update.
# Processing track: Track01557
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01557\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01557\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01557\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01557\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01557\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01557\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01557\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01557\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01557\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01557\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01557\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01557
# Processing track: Track01558
# Stems to remove: []
# No stems removed for Track01558. Skipping mix update.
# Processing track: Track01559
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01559\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01559\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01559\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01559\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01559\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01559\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01559\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01559\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01559\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01559\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01559\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track01559
# Processing track: Track01560
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_validation\Track01560\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_validation\\Track01560\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01560\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track01560
# Processing track: Track01561
# Stems to remove: []
# No stems removed for Track01561. Skipping mix update.
# Processing track: Track01563
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_validation\Track01563\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01563\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01563\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01563\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01563\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01563\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01563\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_validation\\Track01563\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01563\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01563\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01563\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01563\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01563\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01563\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01563\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track01563
# Processing track: Track01564
# Stems to remove: []
# No stems removed for Track01564. Skipping mix update.
# Processing track: Track01565
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01565\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01565\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01565\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01565\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01565\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01565\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01565\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01565\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01565\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01565\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01565\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01565\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01565\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track01565
# Processing track: Track01566
# Stems to remove: ['S09']
# Removing slakh2100_flac_redux/reduced_validation\Track01566\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01566\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01566\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01566\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01566\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01566\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01566\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01566\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01566\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01566\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01566\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01566
# Processing track: Track01568
# Stems to remove: []
# No stems removed for Track01568. Skipping mix update.
# Processing track: Track01570
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_validation\Track01570\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01570\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01570\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01570\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01570\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01570\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01570\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01570\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01570\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01570\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01570\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01570
# Processing track: Track01571
# Stems to remove: []
# No stems removed for Track01571. Skipping mix update.
# Processing track: Track01573
# Stems to remove: []
# No stems removed for Track01573. Skipping mix update.
# Processing track: Track01574
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_validation\Track01574\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01574\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01574\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01574
# Processing track: Track01575
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_validation\Track01575\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01575\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01575\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01575\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01575\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01575\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01575\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01575\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01575\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01575\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01575\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01575\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01575\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01575\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01575\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01575
# Processing track: Track01576
# Stems to remove: []
# No stems removed for Track01576. Skipping mix update.
# Processing track: Track01578
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_validation\Track01578\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_validation\\Track01578\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01578\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track01578
# Processing track: Track01579
# Stems to remove: []
# No stems removed for Track01579. Skipping mix update.
# Processing track: Track01580
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01580\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01580\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01580\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01580\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01580\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01580\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01580\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01580\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01580\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01580\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01580\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01580
# Processing track: Track01581
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_validation\Track01581\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01581\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01581\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track01581
# Processing track: Track01582
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_validation\Track01582\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01582\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01582\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01582\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01582\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01582\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01582\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01582\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01582\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01582\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01582\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01582\stems\S05.flac
# ...
# Mixing slakh2100_flac_redux/reduced_validation\Track01823\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01823\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01823\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01823\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track01823
# Processing track: Track01824
# Stems to remove: []
# No stems removed for Track01824. Skipping mix update.
# Processing track: Track01825
# Stems to remove: ['S02', 'S11']
# Removing slakh2100_flac_redux/reduced_validation\Track01825\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_validation\Track01825\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01825\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01825\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01825\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01825\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01825\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01825\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01825\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01825\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track01825
# Processing track: Track01826
# Stems to remove: []
# No stems removed for Track01826. Skipping mix update.
# Processing track: Track01827
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_validation\Track01827\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01827\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01827\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01827\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01827\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01827\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01827\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01827\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01827\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01827\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01827\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track01827
# Processing track: Track01828
# Stems to remove: []
# No stems removed for Track01828. Skipping mix update.
# Processing track: Track01830
# Stems to remove: []
# No stems removed for Track01830. Skipping mix update.
# Processing track: Track01835
# Stems to remove: []
# No stems removed for Track01835. Skipping mix update.
# Processing track: Track01836
# Stems to remove: []
# No stems removed for Track01836. Skipping mix update.
# Processing track: Track01837
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_validation\Track01837\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_validation\\Track01837\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01837\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track01837
# Processing track: Track01838
# Stems to remove: ['S09']
# Removing slakh2100_flac_redux/reduced_validation\Track01838\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01838\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01838\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01838\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01838\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01838\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_validation\\Track01838\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01838\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01838\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01838\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01838\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01838\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01838\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01838
# Processing track: Track01840
# Stems to remove: []
# No stems removed for Track01840. Skipping mix update.
# Processing track: Track01841
# Stems to remove: []
# No stems removed for Track01841. Skipping mix update.
# Processing track: Track01843
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_validation\Track01843\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01843\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01843\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01843\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01843\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01843\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01843\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01843\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01843\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01843\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01843\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01843
# Processing track: Track01845
# Stems to remove: []
# No stems removed for Track01845. Skipping mix update.
# Processing track: Track01848
# Stems to remove: []
# No stems removed for Track01848. Skipping mix update.
# Processing track: Track01849
# Stems to remove: []
# No stems removed for Track01849. Skipping mix update.
# Processing track: Track01851
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_validation\Track01851\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01851\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01851\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01851\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01851\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01851\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01851\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01851\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01851\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01851\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01851\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01851\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01851\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01851\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01851\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01851
# Processing track: Track01852
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_validation\Track01852\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01852\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01852\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01852\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01852\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01852\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01852\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01852\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01852\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01852\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01852\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01852\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01852\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01852\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01852\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track01852
# Processing track: Track01855
# Stems to remove: []
# No stems removed for Track01855. Skipping mix update.
# Processing track: Track01856
# Stems to remove: []
# No stems removed for Track01856. Skipping mix update.
# Processing track: Track01858
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_validation\Track01858\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01858\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01858\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01858\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01858\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01858\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01858\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01858\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01858\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01858\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01858\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track01858
# Processing track: Track01860
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_validation\Track01860\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01860\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01860\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01860\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01860\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01860\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01860\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01860\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01860\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01860\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01860\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01860\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01860\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01860
# Processing track: Track01861
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_validation\Track01861\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01861\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01861\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01861\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01861\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01861\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01861\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01861\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01861\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01861\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01861\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01861\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01861\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01861
# Processing track: Track01865
# Stems to remove: ['S00', 'S03']
# Removing slakh2100_flac_redux/reduced_validation\Track01865\stems\S00.flac
# Removing slakh2100_flac_redux/reduced_validation\Track01865\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01865\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01865\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_validation\\Track01865\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01865\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_validation\\Track01865\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_validation\\Track01865\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01865\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01865\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01865\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01865\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01865\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01865\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track01865
# Processing track: Track01867
# Stems to remove: []
# No stems removed for Track01867. Skipping mix update.
# Processing track: Track01869
# Stems to remove: []
# No stems removed for Track01869. Skipping mix update.
# Processing track: Track01870
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_validation\Track01870\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01870\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_validation\\Track01870\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_validation\\Track01870\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_validation\\Track01870\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_validation\\Track01870\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01870\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01870\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01870\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01870\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01870\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track01870
# Processing track: Track01873
# Stems to remove: []
# No stems removed for Track01873. Skipping mix update.
# Processing track: Track01874
# Stems to remove: []
# No stems removed for Track01874. Skipping mix update.
# Processing track: Track01875
# Stems to remove: ['S09']
# Removing slakh2100_flac_redux/reduced_validation\Track01875\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_validation\\Track01875\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_validation\\Track01875\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_validation\\Track01875\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_validation\\Track01875\\stems\\S15.flac', 'slakh2100_flac_redux/reduced_validation\\Track01875\\stems\\S17.flac']
# Mixing slakh2100_flac_redux/reduced_validation\Track01875\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01875\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01875\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01875\stems\S15.flac
# Mixing slakh2100_flac_redux/reduced_validation\Track01875\stems\S17.flac
# Exporting mixed file
# Finished processing track: Track01875
