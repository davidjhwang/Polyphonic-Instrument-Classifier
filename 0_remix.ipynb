# %%
import os
import yaml
from pydub import AudioSegment
import time

program_nums_to_remove = {46, 47, 52, 53, 54, 55, 69, 70, 76, 77, 78, 79}
piano_plugins_to_remove = {"scarbee_a_200.nkm", "scarbee_mark_I.nkm", "scarbee_pianet.nkm", "wurly_ep.nkm"}
# brass_plugins_to_remove = {"None", "session_horns_pro_keyswitch_60s_horns.nkm", "trombone_section.nkm", "mute_trumpet.nkm", "tuba.nkm", "horn_1_essential.nkm", "muted_trumpet.nkm"}

# Define the sets to process
data_sets = [
    "slakh2100_flac_redux/reduced_train",
    "slakh2100_flac_redux/reduced_validation",
    "slakh2100_flac_redux/reduced_test",
]

for DIR_PATH in data_sets:
    print(f"\nProcessing data set: {DIR_PATH}")  # Indicate current dataset

    # Iterate through each track folder
    for track in os.listdir(DIR_PATH):
        track_path = os.path.join(DIR_PATH, track)
        metadata_path = os.path.join(track_path, "metadata.yaml")
        stems_path = os.path.join(track_path, "stems")
        mix_path = os.path.join(track_path, "mix.flac")

        if not os.path.isdir(track_path) or not os.path.exists(metadata_path):
            continue

        print(f"Processing track: {track}")

        with open(metadata_path, "r") as f:
            metadata = yaml.safe_load(f)

        if "stems" not in metadata:
            continue

        stems_to_remove = []
        for stem_id, stem_data in metadata["stems"].items():
            inst_class = stem_data.get("inst_class", "")
            program_num = stem_data.get("program_num", None)
            plugin_name = stem_data.get("plugin_name", None)

            if (inst_class in {"Chromatic Percussion", "Organ", "Synth Lead", "Synth Pad", "Sound Effects", "Ethnic", "Percussive", "Sound effects", "Brass", "Reed", "Pipe"} or
                program_num in program_nums_to_remove or
                (inst_class == "Piano" and plugin_name and plugin_name in piano_plugins_to_remove)):
                stems_to_remove.append(stem_id)

        print(f"Stems to remove: {stems_to_remove}")

        if not stems_to_remove:
            print(f"No stems removed for {track}. Skipping mix update.")
            continue

        for stem_id in stems_to_remove:
            stem_file = os.path.join(stems_path, f"{stem_id}.flac")
            if os.path.exists(stem_file):
                print(f"Removing {stem_file}")
                os.remove(stem_file)
            del metadata["stems"][stem_id]

        with open(metadata_path, "w") as f:
            yaml.dump(metadata, f, default_flow_style=False)

        remaining_stems = [os.path.join(stems_path, f"{stem_id}.flac") for stem_id in metadata["stems"] if os.path.exists(os.path.join(stems_path, f"{stem_id}.flac"))]
        print(f"Remaining stems: {remaining_stems}")

        if remaining_stems:
            mixed_audio = None
            for stem_file in remaining_stems:
                print(f"Mixing {stem_file}")
                audio = AudioSegment.from_file(stem_file)
                mixed_audio = audio if mixed_audio is None else mixed_audio.overlay(audio)
            print("Exporting mixed file")
            mixed_audio.export(mix_path, format="flac")
        else:
            print(f"Deleting track folder: {track_path}")
            for root, dirs, files in os.walk(track_path, topdown=False):
                for file in files:
                    file_path = os.path.join(root, file)
                    print(f"Deleting file: {file_path}")
                    os.remove(file_path)
                for dir in dirs:
                    dir_path = os.path.join(root, dir)
                    print(f"Deleting dir: {dir_path}")
                    os.rmdir(dir_path)
            print(f"Removing empty track folder: {track_path}")
            os.rmdir(track_path)

        print(f"Finished processing track: {track}")
        time.sleep(0.1)
# Out:
# Processing data set: slakh2100_flac_redux/reduced_train
# Processing track: Track00001
# Stems to remove: []
# No stems removed for Track00001. Skipping mix update.
# Processing track: Track00002
# Stems to remove: []
# No stems removed for Track00002. Skipping mix update.
# Processing track: Track00003
# Stems to remove: []
# No stems removed for Track00003. Skipping mix update.
# Processing track: Track00004
# Stems to remove: []
# No stems removed for Track00004. Skipping mix update.
# Processing track: Track00005
# Stems to remove: []
# No stems removed for Track00005. Skipping mix update.
# Processing track: Track00006
# Stems to remove: ['S02', 'S07', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track00006\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_train\Track00006\stems\S07.flac
# Removing slakh2100_flac_redux/reduced_train\Track00006\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track00006
# Processing track: Track00007
# Stems to remove: []
# No stems removed for Track00007. Skipping mix update.
# Processing track: Track00008
# Stems to remove: []
# No stems removed for Track00008. Skipping mix update.
# Processing track: Track00009
# Stems to remove: []
# No stems removed for Track00009. Skipping mix update.
# Processing track: Track00010
# Stems to remove: []
# No stems removed for Track00010. Skipping mix update.
# Processing track: Track00011
# Stems to remove: []
# No stems removed for Track00011. Skipping mix update.
# Processing track: Track00012
# Stems to remove: []
# No stems removed for Track00012. Skipping mix update.
# Processing track: Track00013
# Stems to remove: []
# No stems removed for Track00013. Skipping mix update.
# Processing track: Track00014
# Stems to remove: ['S00', 'S09']
# Removing slakh2100_flac_redux/reduced_train\Track00014\stems\S00.flac
# Removing slakh2100_flac_redux/reduced_train\Track00014\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00014
# Processing track: Track00015
# Stems to remove: []
# No stems removed for Track00015. Skipping mix update.
# Processing track: Track00016
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00016\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S15.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S15.flac
# Exporting mixed file
# Finished processing track: Track00016
# Processing track: Track00017
# Stems to remove: []
# No stems removed for Track00017. Skipping mix update.
# Processing track: Track00018
# Stems to remove: []
# No stems removed for Track00018. Skipping mix update.
# Processing track: Track00019
# Stems to remove: []
# No stems removed for Track00019. Skipping mix update.
# Processing track: Track00020
# Stems to remove: []
# No stems removed for Track00020. Skipping mix update.
# Processing track: Track00021
# Stems to remove: []
# No stems removed for Track00021. Skipping mix update.
# Processing track: Track00022
# Stems to remove: []
# No stems removed for Track00022. Skipping mix update.
# Processing track: Track00023
# Stems to remove: []
# No stems removed for Track00023. Skipping mix update.
# Processing track: Track00024
# Stems to remove: ['S10']
# Removing slakh2100_flac_redux/reduced_train\Track00024\stems\S10.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00024
# Processing track: Track00025
# Stems to remove: []
# No stems removed for Track00025. Skipping mix update.
# Processing track: Track00026
# Stems to remove: []
# No stems removed for Track00026. Skipping mix update.
# Processing track: Track00027
# Stems to remove: []
# No stems removed for Track00027. Skipping mix update.
# Processing track: Track00028
# Stems to remove: ['S09']
# Removing slakh2100_flac_redux/reduced_train\Track00028\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00028
# Processing track: Track00029
# Stems to remove: []
# No stems removed for Track00029. Skipping mix update.
# Processing track: Track00030
# Stems to remove: []
# No stems removed for Track00030. Skipping mix update.
# Processing track: Track00031
# Stems to remove: []
# No stems removed for Track00031. Skipping mix update.
# Processing track: Track00032
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00032\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00032\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00032\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00032
# Processing track: Track00033
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00033\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00033
# Processing track: Track00034
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00034\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00034
# Processing track: Track00035
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00035\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00035\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00035\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00035
# Processing track: Track00036
# Stems to remove: []
# No stems removed for Track00036. Skipping mix update.
# Processing track: Track00037
# Stems to remove: []
# No stems removed for Track00037. Skipping mix update.
# Processing track: Track00038
# Stems to remove: []
# No stems removed for Track00038. Skipping mix update.
# Processing track: Track00039
# Stems to remove: []
# No stems removed for Track00039. Skipping mix update.
# Processing track: Track00040
# Stems to remove: []
# No stems removed for Track00040. Skipping mix update.
# Processing track: Track00041
# Stems to remove: []
# No stems removed for Track00041. Skipping mix update.
# Processing track: Track00042
# Stems to remove: []
# No stems removed for Track00042. Skipping mix update.
# Processing track: Track00043
# Stems to remove: []
# No stems removed for Track00043. Skipping mix update.
# Processing track: Track00044
# Stems to remove: []
# No stems removed for Track00044. Skipping mix update.
# Processing track: Track00045
# Stems to remove: []
# No stems removed for Track00045. Skipping mix update.
# Processing track: Track00046
# Stems to remove: []
# No stems removed for Track00046. Skipping mix update.
# Processing track: Track00047
# Stems to remove: []
# No stems removed for Track00047. Skipping mix update.
# Processing track: Track00048
# Stems to remove: ['S13']
# Removing slakh2100_flac_redux/reduced_train\Track00048\stems\S13.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S16.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S17.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S16.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S17.flac
# Exporting mixed file
# Finished processing track: Track00048
# Processing track: Track00050
# Stems to remove: []
# No stems removed for Track00050. Skipping mix update.
# Processing track: Track00051
# Stems to remove: []
# No stems removed for Track00051. Skipping mix update.
# Processing track: Track00052
# Stems to remove: []
# No stems removed for Track00052. Skipping mix update.
# Processing track: Track00053
# Stems to remove: []
# No stems removed for Track00053. Skipping mix update.
# Processing track: Track00054
# Stems to remove: ['S04', 'S05', 'S13']
# Removing slakh2100_flac_redux/reduced_train\Track00054\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track00054\stems\S05.flac
# Removing slakh2100_flac_redux/reduced_train\Track00054\stems\S13.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track00054
# Processing track: Track00055
# Stems to remove: []
# No stems removed for Track00055. Skipping mix update.
# Processing track: Track00056
# Stems to remove: []
# No stems removed for Track00056. Skipping mix update.
# Processing track: Track00057
# Stems to remove: ['S01', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track00057\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_train\Track00057\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00057
# Processing track: Track00058
# Stems to remove: []
# No stems removed for Track00058. Skipping mix update.
# Processing track: Track00059
# Stems to remove: []
# No stems removed for Track00059. Skipping mix update.
# Processing track: Track00060
# Stems to remove: []
# No stems removed for Track00060. Skipping mix update.
# Processing track: Track00061
# Stems to remove: []
# No stems removed for Track00061. Skipping mix update.
# Processing track: Track00062
# Stems to remove: []
# No stems removed for Track00062. Skipping mix update.
# Processing track: Track00063
# Stems to remove: []
# No stems removed for Track00063. Skipping mix update.
# Processing track: Track00064
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00064\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00064
# Processing track: Track00065
# Stems to remove: []
# No stems removed for Track00065. Skipping mix update.
# Processing track: Track00066
# Stems to remove: []
# No stems removed for Track00066. Skipping mix update.
# Processing track: Track00067
# Stems to remove: []
# No stems removed for Track00067. Skipping mix update.
# Processing track: Track00068
# Stems to remove: []
# No stems removed for Track00068. Skipping mix update.
# Processing track: Track00069
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00069\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00069\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00069\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00069
# Processing track: Track00070
# Stems to remove: []
# No stems removed for Track00070. Skipping mix update.
# Processing track: Track00071
# Stems to remove: []
# No stems removed for Track00071. Skipping mix update.
# Processing track: Track00072
# Stems to remove: []
# No stems removed for Track00072. Skipping mix update.
# Processing track: Track00073
# Stems to remove: []
# No stems removed for Track00073. Skipping mix update.
# Processing track: Track00074
# Stems to remove: []
# No stems removed for Track00074. Skipping mix update.
# Processing track: Track00075
# Stems to remove: []
# No stems removed for Track00075. Skipping mix update.
# Processing track: Track00076
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00076\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00076\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00076\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00076\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00076\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00076\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00076\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00076\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00076\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00076\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00076\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00076\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00076\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00076
# Processing track: Track00078
# Stems to remove: []
# No stems removed for Track00078. Skipping mix update.
# Processing track: Track00079
# Stems to remove: []
# No stems removed for Track00079. Skipping mix update.
# Processing track: Track00080
# Stems to remove: []
# No stems removed for Track00080. Skipping mix update.
# Processing track: Track00081
# Stems to remove: []
# No stems removed for Track00081. Skipping mix update.
# Processing track: Track00082
# Stems to remove: []
# No stems removed for Track00082. Skipping mix update.
# Processing track: Track00083
# Stems to remove: []
# No stems removed for Track00083. Skipping mix update.
# Processing track: Track00084
# Stems to remove: []
# No stems removed for Track00084. Skipping mix update.
# Processing track: Track00085
# Stems to remove: []
# No stems removed for Track00085. Skipping mix update.
# Processing track: Track00086
# Stems to remove: ['S08', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track00086\stems\S08.flac
# Removing slakh2100_flac_redux/reduced_train\Track00086\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track00086\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00086\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track00086
# Processing track: Track00087
# Stems to remove: []
# No stems removed for Track00087. Skipping mix update.
# Processing track: Track00088
# Stems to remove: []
# No stems removed for Track00088. Skipping mix update.
# Processing track: Track00089
# Stems to remove: []
# No stems removed for Track00089. Skipping mix update.
# Processing track: Track00090
# Stems to remove: []
# No stems removed for Track00090. Skipping mix update.
# Processing track: Track00091
# Stems to remove: []
# No stems removed for Track00091. Skipping mix update.
# Processing track: Track00092
# Stems to remove: []
# No stems removed for Track00092. Skipping mix update.
# Processing track: Track00093
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00093\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00093\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00093\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00093\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00093\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00093\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00093\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00093\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00093\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00093\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00093\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00093\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00093\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00093
# Processing track: Track00094
# Stems to remove: []
# No stems removed for Track00094. Skipping mix update.
# Processing track: Track00095
# Stems to remove: ['S02', 'S05']
# Removing slakh2100_flac_redux/reduced_train\Track00095\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_train\Track00095\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00095\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00095\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00095\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00095\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00095\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00095\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00095\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00095\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00095\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00095\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00095\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00095\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00095\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00095\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track00095
# Processing track: Track00096
# Stems to remove: []
# No stems removed for Track00096. Skipping mix update.
# Processing track: Track00097
# Stems to remove: []
# No stems removed for Track00097. Skipping mix update.
# Processing track: Track00098
# Stems to remove: []
# No stems removed for Track00098. Skipping mix update.
# Processing track: Track00099
# Stems to remove: []
# No stems removed for Track00099. Skipping mix update.
# Processing track: Track00100
# Stems to remove: []
# No stems removed for Track00100. Skipping mix update.
# Processing track: Track00101
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_train\Track00101\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00101\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00101\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00101\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00101\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00101\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00101\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00101\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00101\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00101\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00101\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00101\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00101\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00101\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00101\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00101
# Processing track: Track00102
# Stems to remove: []
# No stems removed for Track00102. Skipping mix update.
# Processing track: Track00103
# Stems to remove: []
# No stems removed for Track00103. Skipping mix update.
# Processing track: Track00104
# Stems to remove: []
# No stems removed for Track00104. Skipping mix update.
# Processing track: Track00105
# Stems to remove: ['S01', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track00105\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_train\Track00105\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00105\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00105\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00105\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00105\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00105\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00105\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00105\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00105\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00105\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00105\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00105\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00105\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00105
# Processing track: Track00106
# Stems to remove: []
# No stems removed for Track00106. Skipping mix update.
# Processing track: Track00107
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00107\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00107\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00107\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00107\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00107\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00107\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00107\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00107\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00107\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00107\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00107\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track00107
# Processing track: Track00108
# Stems to remove: []
# No stems removed for Track00108. Skipping mix update.
# Processing track: Track00109
# Stems to remove: []
# No stems removed for Track00109. Skipping mix update.
# Processing track: Track00110
# Stems to remove: ['S12']
# Removing slakh2100_flac_redux/reduced_train\Track00110\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00110\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00110\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00110\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00110\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00110\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00110\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00110\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00110\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00110\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00110\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00110\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00110\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00110\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00110\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track00110
# Processing track: Track00111
# Stems to remove: []
# No stems removed for Track00111. Skipping mix update.
# Processing track: Track00112
# Stems to remove: []
# No stems removed for Track00112. Skipping mix update.
# Processing track: Track00113
# Stems to remove: []
# No stems removed for Track00113. Skipping mix update.
# Processing track: Track00114
# Stems to remove: []
# No stems removed for Track00114. Skipping mix update.
# Processing track: Track00115
# Stems to remove: ['S08', 'S10']
# Removing slakh2100_flac_redux/reduced_train\Track00115\stems\S08.flac
# Removing slakh2100_flac_redux/reduced_train\Track00115\stems\S10.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00115\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00115\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00115\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00115\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00115\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00115\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00115\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00115\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00115\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00115\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00115\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00115\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00115\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00115\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00115
# Processing track: Track00116
# Stems to remove: []
# No stems removed for Track00116. Skipping mix update.
# Processing track: Track00117
# Stems to remove: []
# No stems removed for Track00117. Skipping mix update.
# Processing track: Track00118
# Stems to remove: []
# No stems removed for Track00118. Skipping mix update.
# Processing track: Track00119
# Stems to remove: []
# No stems removed for Track00119. Skipping mix update.
# Processing track: Track00120
# Stems to remove: []
# No stems removed for Track00120. Skipping mix update.
# Processing track: Track00121
# Stems to remove: []
# No stems removed for Track00121. Skipping mix update.
# Processing track: Track00122
# Stems to remove: []
# No stems removed for Track00122. Skipping mix update.
# Processing track: Track00123
# Stems to remove: []
# No stems removed for Track00123. Skipping mix update.
# Processing track: Track00124
# Stems to remove: []
# No stems removed for Track00124. Skipping mix update.
# Processing track: Track00125
# Stems to remove: []
# No stems removed for Track00125. Skipping mix update.
# Processing track: Track00126
# Stems to remove: []
# No stems removed for Track00126. Skipping mix update.
# Processing track: Track00127
# Stems to remove: []
# No stems removed for Track00127. Skipping mix update.
# Processing track: Track00128
# Stems to remove: []
# No stems removed for Track00128. Skipping mix update.
# Processing track: Track00129
# Stems to remove: []
# No stems removed for Track00129. Skipping mix update.
# Processing track: Track00130
# Stems to remove: []
# No stems removed for Track00130. Skipping mix update.
# Processing track: Track00131
# Stems to remove: ['S09']
# Removing slakh2100_flac_redux/reduced_train\Track00131\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00131\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00131\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00131\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00131\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00131\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00131\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00131\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00131\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00131\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00131\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00131\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00131\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00131\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00131\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track00131
# Processing track: Track00132
# Stems to remove: []
# No stems removed for Track00132. Skipping mix update.
# Processing track: Track00133
# Stems to remove: []
# No stems removed for Track00133. Skipping mix update.
# Processing track: Track00134
# Stems to remove: []
# No stems removed for Track00134. Skipping mix update.
# Processing track: Track00135
# Stems to remove: []
# No stems removed for Track00135. Skipping mix update.
# Processing track: Track00136
# Stems to remove: []
# No stems removed for Track00136. Skipping mix update.
# Processing track: Track00137
# Stems to remove: ['S11']
# Removing slakh2100_flac_redux/reduced_train\Track00137\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00137\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00137\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00137\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00137\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00137\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00137\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00137\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00137\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00137\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00137\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00137\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00137\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00137\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00137\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00137
# Processing track: Track00138
# Stems to remove: []
# No stems removed for Track00138. Skipping mix update.
# Processing track: Track00139
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track00139\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00139\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00139\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00139\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00139\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00139\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00139\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00139\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00139\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00139\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00139\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00139
# Processing track: Track00140
# Stems to remove: []
# No stems removed for Track00140. Skipping mix update.
# Processing track: Track00141
# Stems to remove: ['S08', 'S11']
# Removing slakh2100_flac_redux/reduced_train\Track00141\stems\S08.flac
# Removing slakh2100_flac_redux/reduced_train\Track00141\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00141\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00141\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00141\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00141\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00141\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00141\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00141\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00141\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track00141
# Processing track: Track00142
# Stems to remove: []
# No stems removed for Track00142. Skipping mix update.
# Processing track: Track00143
# Stems to remove: []
# No stems removed for Track00143. Skipping mix update.
# Processing track: Track00144
# Stems to remove: []
# No stems removed for Track00144. Skipping mix update.
# Processing track: Track00145
# Stems to remove: []
# No stems removed for Track00145. Skipping mix update.
# Processing track: Track00147
# Stems to remove: []
# No stems removed for Track00147. Skipping mix update.
# Processing track: Track00148
# Stems to remove: []
# No stems removed for Track00148. Skipping mix update.
# Processing track: Track00149
# Stems to remove: []
# No stems removed for Track00149. Skipping mix update.
# Processing track: Track00150
# Stems to remove: []
# No stems removed for Track00150. Skipping mix update.
# Processing track: Track00151
# Stems to remove: []
# No stems removed for Track00151. Skipping mix update.
# Processing track: Track00152
# Stems to remove: []
# No stems removed for Track00152. Skipping mix update.
# Processing track: Track00153
# Stems to remove: []
# No stems removed for Track00153. Skipping mix update.
# Processing track: Track00154
# Stems to remove: []
# No stems removed for Track00154. Skipping mix update.
# Processing track: Track00155
# Stems to remove: []
# No stems removed for Track00155. Skipping mix update.
# Processing track: Track00156
# Stems to remove: []
# No stems removed for Track00156. Skipping mix update.
# Processing track: Track00157
# Stems to remove: []
# No stems removed for Track00157. Skipping mix update.
# Processing track: Track00158
# Stems to remove: []
# No stems removed for Track00158. Skipping mix update.
# Processing track: Track00159
# Stems to remove: []
# No stems removed for Track00159. Skipping mix update.
# Processing track: Track00160
# Stems to remove: []
# No stems removed for Track00160. Skipping mix update.
# Processing track: Track00161
# Stems to remove: []
# No stems removed for Track00161. Skipping mix update.
# Processing track: Track00162
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00162\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00162\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00162\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00162\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00162\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00162\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00162\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00162\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00162\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00162\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00162\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00162
# Processing track: Track00163
# Stems to remove: []
# No stems removed for Track00163. Skipping mix update.
# Processing track: Track00164
# Stems to remove: []
# No stems removed for Track00164. Skipping mix update.
# Processing track: Track00165
# Stems to remove: []
# No stems removed for Track00165. Skipping mix update.
# Processing track: Track00166
# Stems to remove: []
# No stems removed for Track00166. Skipping mix update.
# Processing track: Track00167
# Stems to remove: []
# No stems removed for Track00167. Skipping mix update.
# Processing track: Track00168
# Stems to remove: ['S13']
# Removing slakh2100_flac_redux/reduced_train\Track00168\stems\S13.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00168\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00168\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00168\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00168\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00168\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00168\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00168\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00168\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00168\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00168\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00168\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00168\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00168\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00168\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00168
# Processing track: Track00169
# Stems to remove: []
# No stems removed for Track00169. Skipping mix update.
# Processing track: Track00171
# Stems to remove: ['S09']
# Removing slakh2100_flac_redux/reduced_train\Track00171\stems\S09.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00171\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00171\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00171\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00171\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00171\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_train\\Track00171\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00171\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00171\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00171\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00171\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00171\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00171\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00171
# Processing track: Track00172
# Stems to remove: []
# No stems removed for Track00172. Skipping mix update.
# Processing track: Track00173
# Stems to remove: []
# No stems removed for Track00173. Skipping mix update.
# Processing track: Track00174
# Stems to remove: []
# No stems removed for Track00174. Skipping mix update.
# Processing track: Track00175
# Stems to remove: []
# No stems removed for Track00175. Skipping mix update.
# Processing track: Track00176
# Stems to remove: []
# No stems removed for Track00176. Skipping mix update.
# Processing track: Track00177
# Stems to remove: ['S06', 'S08']
# Removing slakh2100_flac_redux/reduced_train\Track00177\stems\S06.flac
# Removing slakh2100_flac_redux/reduced_train\Track00177\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track00177\\stems\\S14.flac']
# ...
# Mixing slakh2100_flac_redux/reduced_test\Track02008\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02008\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02008\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02008\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track02008
# Processing track: Track02010
# Stems to remove: ['S06', 'S13']
# Removing slakh2100_flac_redux/reduced_test\Track02010\stems\S06.flac
# Removing slakh2100_flac_redux/reduced_test\Track02010\stems\S13.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02010\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02010\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02010\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02010\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02010\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02010\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02010\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02010\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02010\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02010\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02010\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02010\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02010\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02010\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track02010
# Processing track: Track02013
# Stems to remove: []
# No stems removed for Track02013. Skipping mix update.
# Processing track: Track02014
# Stems to remove: []
# No stems removed for Track02014. Skipping mix update.
# Processing track: Track02016
# Stems to remove: []
# No stems removed for Track02016. Skipping mix update.
# Processing track: Track02017
# Stems to remove: []
# No stems removed for Track02017. Skipping mix update.
# Processing track: Track02018
# Stems to remove: []
# No stems removed for Track02018. Skipping mix update.
# Processing track: Track02019
# Stems to remove: []
# No stems removed for Track02019. Skipping mix update.
# Processing track: Track02020
# Stems to remove: []
# No stems removed for Track02020. Skipping mix update.
# Processing track: Track02023
# Stems to remove: []
# No stems removed for Track02023. Skipping mix update.
# Processing track: Track02024
# Stems to remove: ['S12']
# Removing slakh2100_flac_redux/reduced_test\Track02024\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02024\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02024\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02024\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02024\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02024\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02024\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_test\\Track02024\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02024\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02024\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02024\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02024\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02024\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02024\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02024\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track02024
# Processing track: Track02026
# Stems to remove: []
# No stems removed for Track02026. Skipping mix update.
# Processing track: Track02029
# Stems to remove: []
# No stems removed for Track02029. Skipping mix update.
# Processing track: Track02030
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_test\Track02030\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02030\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02030\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02030\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02030\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02030\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02030\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02030\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02030\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02030\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02030\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track02030
# Processing track: Track02031
# Stems to remove: []
# No stems removed for Track02031. Skipping mix update.
# Processing track: Track02032
# Stems to remove: []
# No stems removed for Track02032. Skipping mix update.
# Processing track: Track02036
# Stems to remove: []
# No stems removed for Track02036. Skipping mix update.
# Processing track: Track02037
# Stems to remove: []
# No stems removed for Track02037. Skipping mix update.
# Processing track: Track02038
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_test\Track02038\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02038\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02038\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track02038
# Processing track: Track02040
# Stems to remove: []
# No stems removed for Track02040. Skipping mix update.
# Processing track: Track02042
# Stems to remove: []
# No stems removed for Track02042. Skipping mix update.
# Processing track: Track02044
# Stems to remove: []
# No stems removed for Track02044. Skipping mix update.
# Processing track: Track02045
# Stems to remove: []
# No stems removed for Track02045. Skipping mix update.
# Processing track: Track02046
# Stems to remove: []
# No stems removed for Track02046. Skipping mix update.
# Processing track: Track02047
# Stems to remove: []
# No stems removed for Track02047. Skipping mix update.
# Processing track: Track02048
# Stems to remove: []
# No stems removed for Track02048. Skipping mix update.
# Processing track: Track02049
# Stems to remove: []
# No stems removed for Track02049. Skipping mix update.
# Processing track: Track02050
# Stems to remove: []
# No stems removed for Track02050. Skipping mix update.
# Processing track: Track02051
# Stems to remove: []
# No stems removed for Track02051. Skipping mix update.
# Processing track: Track02052
# Stems to remove: []
# No stems removed for Track02052. Skipping mix update.
# Processing track: Track02053
# Stems to remove: ['S12']
# Removing slakh2100_flac_redux/reduced_test\Track02053\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02053\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02053\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02053\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02053\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02053\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_test\\Track02053\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02053\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02053\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02053\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02053\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02053\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02053\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track02053
# Processing track: Track02054
# Stems to remove: ['S11', 'S12']
# Removing slakh2100_flac_redux/reduced_test\Track02054\stems\S11.flac
# Removing slakh2100_flac_redux/reduced_test\Track02054\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02054\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02054\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track02054
# Processing track: Track02056
# Stems to remove: []
# No stems removed for Track02056. Skipping mix update.
# Processing track: Track02061
# Stems to remove: []
# No stems removed for Track02061. Skipping mix update.
# Processing track: Track02062
# Stems to remove: []
# No stems removed for Track02062. Skipping mix update.
# Processing track: Track02063
# Stems to remove: []
# No stems removed for Track02063. Skipping mix update.
# Processing track: Track02064
# Stems to remove: []
# No stems removed for Track02064. Skipping mix update.
# Processing track: Track02067
# Stems to remove: []
# No stems removed for Track02067. Skipping mix update.
# Processing track: Track02069
# Stems to remove: ['S12']
# Removing slakh2100_flac_redux/reduced_test\Track02069\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track02069
# Processing track: Track02070
# Stems to remove: []
# No stems removed for Track02070. Skipping mix update.
# Processing track: Track02074
# Stems to remove: []
# No stems removed for Track02074. Skipping mix update.
# Processing track: Track02079
# Stems to remove: []
# No stems removed for Track02079. Skipping mix update.
# Processing track: Track02081
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_test\Track02081\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track02081
# Processing track: Track02082
# Stems to remove: []
# No stems removed for Track02082. Skipping mix update.
# Processing track: Track02083
# Stems to remove: []
# No stems removed for Track02083. Skipping mix update.
# Processing track: Track02084
# Stems to remove: []
# No stems removed for Track02084. Skipping mix update.
# Processing track: Track02086
# Stems to remove: []
# No stems removed for Track02086. Skipping mix update.
# Processing track: Track02087
# Stems to remove: []
# No stems removed for Track02087. Skipping mix update.
# Processing track: Track02088
# Stems to remove: []
# No stems removed for Track02088. Skipping mix update.
# Processing track: Track02090
# Stems to remove: []
# No stems removed for Track02090. Skipping mix update.
# Processing track: Track02092
# Stems to remove: ['S09', 'S10']
# Removing slakh2100_flac_redux/reduced_test\Track02092\stems\S09.flac
# Removing slakh2100_flac_redux/reduced_test\Track02092\stems\S10.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02092\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02092\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02092\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02092\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02092\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02092\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02092\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02092\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02092\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02092\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02092\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02092\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02092\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02092\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track02092
# Processing track: Track02093
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_test\Track02093\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02093\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02093\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02093\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02093\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02093\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02093\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02093\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02093\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02093\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02093\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02093\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02093\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track02093
# Processing track: Track02094
# Stems to remove: []
# No stems removed for Track02094. Skipping mix update.
# Processing track: Track02095
# Stems to remove: []
# No stems removed for Track02095. Skipping mix update.
# Processing track: Track02096
# Stems to remove: []
# No stems removed for Track02096. Skipping mix update.
# Processing track: Track02098
# Stems to remove: []
# No stems removed for Track02098. Skipping mix update.
