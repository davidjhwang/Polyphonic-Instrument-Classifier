# %%
import os
import yaml
from pydub import AudioSegment
import time

program_nums_to_remove = {46, 47, 52, 53, 54, 55, 69, 70, 76, 77, 78, 79}
piano_plugins_to_remove = {"scarbee_a_200.nkm", "scarbee_mark_I.nkm", "scarbee_pianet.nkm", "wurly_ep.nkm"}
brass_plugins_to_remove = {"None", "session_horns_pro_keyswitch_60s_horns.nkm", "trombone_section.nkm", "mute_trumpet.nkm", "tuba.nkm", "horn_1_essential.nkm", "muted_trumpet.nkm"}

# Define the sets to process
data_sets = [
    "slakh2100_flac_redux/reduced_train",
    "slakh2100_flac_redux/reduced_validation",
    "slakh2100_flac_redux/reduced_test",
]

for DIR_PATH in data_sets:
    print(f"\nProcessing data set: {DIR_PATH}")  # Indicate current dataset

    # Iterate through each track folder
    for track in os.listdir(DIR_PATH):
        track_path = os.path.join(DIR_PATH, track)
        metadata_path = os.path.join(track_path, "metadata.yaml")
        stems_path = os.path.join(track_path, "stems")
        mix_path = os.path.join(track_path, "mix.flac")

        if not os.path.isdir(track_path) or not os.path.exists(metadata_path):
            continue

        print(f"Processing track: {track}")

        with open(metadata_path, "r") as f:
            metadata = yaml.safe_load(f)

        if "stems" not in metadata:
            continue

        stems_to_remove = []
        for stem_id, stem_data in metadata["stems"].items():
            inst_class = stem_data.get("inst_class", "")
            program_num = stem_data.get("program_num", None)
            plugin_name = stem_data.get("plugin_name", None)

            if (inst_class in {"Chromatic Percussion", "Organ", "Synth Lead", "Synth Pad", "Sound Effects", "Ethnic", "Percussive", "Sound effects", "Reed", "Pipe"} or
                program_num in program_nums_to_remove or
                (inst_class == "Piano" and plugin_name and plugin_name in piano_plugins_to_remove) or
                (inst_class == "Brass" and plugin_name and plugin_name in brass_plugins_to_remove)):
                stems_to_remove.append(stem_id)

        print(f"Stems to remove: {stems_to_remove}")

        if not stems_to_remove:
            print(f"No stems removed for {track}. Skipping mix update.")
            continue

        for stem_id in stems_to_remove:
            stem_file = os.path.join(stems_path, f"{stem_id}.flac")
            if os.path.exists(stem_file):
                print(f"Removing {stem_file}")
                os.remove(stem_file)
            del metadata["stems"][stem_id]

        with open(metadata_path, "w") as f:
            yaml.dump(metadata, f, default_flow_style=False)

        remaining_stems = [os.path.join(stems_path, f"{stem_id}.flac") for stem_id in metadata["stems"] if os.path.exists(os.path.join(stems_path, f"{stem_id}.flac"))]
        print(f"Remaining stems: {remaining_stems}")

        if remaining_stems:
            mixed_audio = None
            for stem_file in remaining_stems:
                print(f"Mixing {stem_file}")
                audio = AudioSegment.from_file(stem_file)
                mixed_audio = audio if mixed_audio is None else mixed_audio.overlay(audio)
            print("Exporting mixed file")
            mixed_audio.export(mix_path, format="flac")
        else:
            print(f"Deleting track folder: {track_path}")
            for root, dirs, files in os.walk(track_path, topdown=False):
                for file in files:
                    file_path = os.path.join(root, file)
                    print(f"Deleting file: {file_path}")
                    os.remove(file_path)
                for dir in dirs:
                    dir_path = os.path.join(root, dir)
                    print(f"Deleting dir: {dir_path}")
                    os.rmdir(dir_path)
            print(f"Removing empty track folder: {track_path}")
            os.rmdir(track_path)

        print(f"Finished processing track: {track}")
        time.sleep(0.1)
# Out:
# Processing data set: slakh2100_flac_redux/reduced_train
# Processing track: Track00001
# Stems to remove: []
# No stems removed for Track00001. Skipping mix update.
# Processing track: Track00002
# Stems to remove: []
# No stems removed for Track00002. Skipping mix update.
# Processing track: Track00003
# Stems to remove: []
# No stems removed for Track00003. Skipping mix update.
# Processing track: Track00004
# Stems to remove: []
# No stems removed for Track00004. Skipping mix update.
# Processing track: Track00005
# Stems to remove: []
# No stems removed for Track00005. Skipping mix update.
# Processing track: Track00006
# Stems to remove: []
# No stems removed for Track00006. Skipping mix update.
# Processing track: Track00007
# Stems to remove: []
# No stems removed for Track00007. Skipping mix update.
# Processing track: Track00008
# Stems to remove: []
# No stems removed for Track00008. Skipping mix update.
# Processing track: Track00009
# Stems to remove: []
# No stems removed for Track00009. Skipping mix update.
# Processing track: Track00010
# Stems to remove: []
# No stems removed for Track00010. Skipping mix update.
# Processing track: Track00011
# Stems to remove: []
# No stems removed for Track00011. Skipping mix update.
# Processing track: Track00012
# Stems to remove: []
# No stems removed for Track00012. Skipping mix update.
# Processing track: Track00013
# Stems to remove: ['S02']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00013
# Processing track: Track00014
# Stems to remove: []
# No stems removed for Track00014. Skipping mix update.
# Processing track: Track00015
# Stems to remove: []
# No stems removed for Track00015. Skipping mix update.
# Processing track: Track00016
# Stems to remove: []
# No stems removed for Track00016. Skipping mix update.
# Processing track: Track00017
# Stems to remove: []
# No stems removed for Track00017. Skipping mix update.
# Processing track: Track00018
# Stems to remove: []
# No stems removed for Track00018. Skipping mix update.
# Processing track: Track00019
# Stems to remove: []
# No stems removed for Track00019. Skipping mix update.
# Processing track: Track00020
# Stems to remove: []
# No stems removed for Track00020. Skipping mix update.
# Processing track: Track00021
# Stems to remove: []
# No stems removed for Track00021. Skipping mix update.
# Processing track: Track00022
# Stems to remove: []
# No stems removed for Track00022. Skipping mix update.
# Processing track: Track00023
# Stems to remove: []
# No stems removed for Track00023. Skipping mix update.
# Processing track: Track00024
# Stems to remove: ['S09']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00024
# Processing track: Track00025
# Stems to remove: ['S05']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00025
# Processing track: Track00026
# Stems to remove: []
# No stems removed for Track00026. Skipping mix update.
# Processing track: Track00027
# Stems to remove: []
# No stems removed for Track00027. Skipping mix update.
# Processing track: Track00028
# Stems to remove: []
# No stems removed for Track00028. Skipping mix update.
# Processing track: Track00029
# Stems to remove: []
# No stems removed for Track00029. Skipping mix update.
# Processing track: Track00030
# Stems to remove: []
# No stems removed for Track00030. Skipping mix update.
# Processing track: Track00031
# Stems to remove: []
# No stems removed for Track00031. Skipping mix update.
# Processing track: Track00032
# Stems to remove: []
# No stems removed for Track00032. Skipping mix update.
# Processing track: Track00033
# Stems to remove: []
# No stems removed for Track00033. Skipping mix update.
# Processing track: Track00034
# Stems to remove: []
# No stems removed for Track00034. Skipping mix update.
# Processing track: Track00035
# Stems to remove: []
# No stems removed for Track00035. Skipping mix update.
# Processing track: Track00036
# Stems to remove: []
# No stems removed for Track00036. Skipping mix update.
# Processing track: Track00037
# Stems to remove: []
# No stems removed for Track00037. Skipping mix update.
# Processing track: Track00038
# Stems to remove: []
# No stems removed for Track00038. Skipping mix update.
# Processing track: Track00039
# Stems to remove: []
# No stems removed for Track00039. Skipping mix update.
# Processing track: Track00040
# Stems to remove: []
# No stems removed for Track00040. Skipping mix update.
# Processing track: Track00041
# Stems to remove: []
# No stems removed for Track00041. Skipping mix update.
# Processing track: Track00042
# Stems to remove: []
# No stems removed for Track00042. Skipping mix update.
# Processing track: Track00043
# Stems to remove: []
# No stems removed for Track00043. Skipping mix update.
# Processing track: Track00044
# Stems to remove: []
# No stems removed for Track00044. Skipping mix update.
# Processing track: Track00045
# Stems to remove: []
# No stems removed for Track00045. Skipping mix update.
# Processing track: Track00046
# Stems to remove: []
# No stems removed for Track00046. Skipping mix update.
# Processing track: Track00047
# Stems to remove: []
# No stems removed for Track00047. Skipping mix update.
# Processing track: Track00048
# Stems to remove: ['S12', 'S19']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S16.flac', 'slakh2100_flac_redux/reduced_train\\Track00048\\stems\\S17.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S16.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00048\stems\S17.flac
# Exporting mixed file
# Finished processing track: Track00048
# Processing track: Track00050
# Stems to remove: []
# No stems removed for Track00050. Skipping mix update.
# Processing track: Track00051
# Stems to remove: []
# No stems removed for Track00051. Skipping mix update.
# Processing track: Track00052
# Stems to remove: []
# No stems removed for Track00052. Skipping mix update.
# Processing track: Track00053
# Stems to remove: []
# No stems removed for Track00053. Skipping mix update.
# Processing track: Track00054
# Stems to remove: []
# No stems removed for Track00054. Skipping mix update.
# Processing track: Track00055
# Stems to remove: []
# No stems removed for Track00055. Skipping mix update.
# Processing track: Track00056
# Stems to remove: []
# No stems removed for Track00056. Skipping mix update.
# Processing track: Track00057
# Stems to remove: []
# No stems removed for Track00057. Skipping mix update.
# Processing track: Track00058
# Stems to remove: []
# No stems removed for Track00058. Skipping mix update.
# Processing track: Track00059
# Stems to remove: []
# No stems removed for Track00059. Skipping mix update.
# Processing track: Track00060
# Stems to remove: []
# No stems removed for Track00060. Skipping mix update.
# Processing track: Track00061
# Stems to remove: []
# No stems removed for Track00061. Skipping mix update.
# Processing track: Track00062
# Stems to remove: []
# No stems removed for Track00062. Skipping mix update.
# Processing track: Track00063
# Stems to remove: []
# No stems removed for Track00063. Skipping mix update.
# Processing track: Track00064
# Stems to remove: []
# No stems removed for Track00064. Skipping mix update.
# Processing track: Track00065
# Stems to remove: []
# No stems removed for Track00065. Skipping mix update.
# Processing track: Track00066
# Stems to remove: []
# No stems removed for Track00066. Skipping mix update.
# Processing track: Track00067
# Stems to remove: []
# No stems removed for Track00067. Skipping mix update.
# Processing track: Track00068
# Stems to remove: []
# No stems removed for Track00068. Skipping mix update.
# Processing track: Track00069
# Stems to remove: []
# No stems removed for Track00069. Skipping mix update.
# Processing track: Track00070
# Stems to remove: []
# No stems removed for Track00070. Skipping mix update.
# Processing track: Track00071
# Stems to remove: []
# No stems removed for Track00071. Skipping mix update.
# Processing track: Track00072
# Stems to remove: []
# No stems removed for Track00072. Skipping mix update.
# Processing track: Track00073
# Stems to remove: []
# No stems removed for Track00073. Skipping mix update.
# Processing track: Track00074
# Stems to remove: []
# No stems removed for Track00074. Skipping mix update.
# Processing track: Track00075
# Stems to remove: []
# No stems removed for Track00075. Skipping mix update.
# Processing track: Track00076
# Stems to remove: []
# No stems removed for Track00076. Skipping mix update.
# Processing track: Track00078
# Stems to remove: []
# No stems removed for Track00078. Skipping mix update.
# Processing track: Track00079
# Stems to remove: []
# No stems removed for Track00079. Skipping mix update.
# Processing track: Track00080
# Stems to remove: []
# No stems removed for Track00080. Skipping mix update.
# Processing track: Track00081
# Stems to remove: []
# No stems removed for Track00081. Skipping mix update.
# Processing track: Track00082
# Stems to remove: []
# No stems removed for Track00082. Skipping mix update.
# Processing track: Track00083
# Stems to remove: []
# No stems removed for Track00083. Skipping mix update.
# Processing track: Track00084
# Stems to remove: []
# No stems removed for Track00084. Skipping mix update.
# Processing track: Track00085
# Stems to remove: []
# No stems removed for Track00085. Skipping mix update.
# Processing track: Track00086
# Stems to remove: []
# No stems removed for Track00086. Skipping mix update.
# Processing track: Track00087
# Stems to remove: []
# No stems removed for Track00087. Skipping mix update.
# Processing track: Track00088
# Stems to remove: []
# No stems removed for Track00088. Skipping mix update.
# Processing track: Track00089
# Stems to remove: []
# No stems removed for Track00089. Skipping mix update.
# Processing track: Track00090
# Stems to remove: []
# No stems removed for Track00090. Skipping mix update.
# Processing track: Track00091
# Stems to remove: []
# No stems removed for Track00091. Skipping mix update.
# Processing track: Track00092
# Stems to remove: []
# No stems removed for Track00092. Skipping mix update.
# Processing track: Track00093
# Stems to remove: []
# No stems removed for Track00093. Skipping mix update.
# Processing track: Track00094
# Stems to remove: []
# No stems removed for Track00094. Skipping mix update.
# Processing track: Track00095
# Stems to remove: []
# No stems removed for Track00095. Skipping mix update.
# Processing track: Track00096
# Stems to remove: []
# No stems removed for Track00096. Skipping mix update.
# Processing track: Track00097
# Stems to remove: []
# No stems removed for Track00097. Skipping mix update.
# Processing track: Track00098
# Stems to remove: []
# No stems removed for Track00098. Skipping mix update.
# Processing track: Track00099
# Stems to remove: []
# No stems removed for Track00099. Skipping mix update.
# Processing track: Track00100
# Stems to remove: []
# No stems removed for Track00100. Skipping mix update.
# Processing track: Track00101
# Stems to remove: []
# No stems removed for Track00101. Skipping mix update.
# Processing track: Track00102
# Stems to remove: []
# No stems removed for Track00102. Skipping mix update.
# Processing track: Track00103
# Stems to remove: ['S07']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00103\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00103\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00103\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00103\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00103\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00103\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00103\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00103\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00103\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00103\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00103\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00103\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00103
# Processing track: Track00104
# Stems to remove: []
# No stems removed for Track00104. Skipping mix update.
# Processing track: Track00105
# Stems to remove: []
# No stems removed for Track00105. Skipping mix update.
# Processing track: Track00106
# Stems to remove: []
# No stems removed for Track00106. Skipping mix update.
# Processing track: Track00107
# Stems to remove: []
# No stems removed for Track00107. Skipping mix update.
# Processing track: Track00108
# Stems to remove: []
# No stems removed for Track00108. Skipping mix update.
# Processing track: Track00109
# Stems to remove: []
# No stems removed for Track00109. Skipping mix update.
# Processing track: Track00110
# Stems to remove: []
# No stems removed for Track00110. Skipping mix update.
# Processing track: Track00111
# Stems to remove: []
# No stems removed for Track00111. Skipping mix update.
# Processing track: Track00112
# Stems to remove: []
# No stems removed for Track00112. Skipping mix update.
# Processing track: Track00113
# Stems to remove: []
# No stems removed for Track00113. Skipping mix update.
# Processing track: Track00114
# Stems to remove: []
# No stems removed for Track00114. Skipping mix update.
# Processing track: Track00115
# Stems to remove: []
# No stems removed for Track00115. Skipping mix update.
# Processing track: Track00116
# Stems to remove: []
# No stems removed for Track00116. Skipping mix update.
# Processing track: Track00117
# Stems to remove: []
# No stems removed for Track00117. Skipping mix update.
# Processing track: Track00118
# Stems to remove: []
# No stems removed for Track00118. Skipping mix update.
# Processing track: Track00119
# Stems to remove: ['S07', 'S08', 'S13']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00119\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00119\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00119\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00119\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00119\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00119\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00119\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00119\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00119\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00119\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00119\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00119\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00119\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00119\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00119
# Processing track: Track00120
# Stems to remove: ['S02', 'S03']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00120\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00120\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00120\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00120\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00120\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00120\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00120\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00120\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00120
# Processing track: Track00121
# Stems to remove: []
# No stems removed for Track00121. Skipping mix update.
# Processing track: Track00122
# Stems to remove: []
# No stems removed for Track00122. Skipping mix update.
# Processing track: Track00123
# Stems to remove: []
# No stems removed for Track00123. Skipping mix update.
# Processing track: Track00124
# Stems to remove: []
# No stems removed for Track00124. Skipping mix update.
# Processing track: Track00125
# Stems to remove: []
# No stems removed for Track00125. Skipping mix update.
# Processing track: Track00126
# Stems to remove: []
# No stems removed for Track00126. Skipping mix update.
# Processing track: Track00127
# Stems to remove: []
# No stems removed for Track00127. Skipping mix update.
# Processing track: Track00128
# Stems to remove: []
# No stems removed for Track00128. Skipping mix update.
# Processing track: Track00129
# Stems to remove: []
# No stems removed for Track00129. Skipping mix update.
# Processing track: Track00130
# Stems to remove: []
# No stems removed for Track00130. Skipping mix update.
# Processing track: Track00131
# Stems to remove: []
# No stems removed for Track00131. Skipping mix update.
# Processing track: Track00132
# Stems to remove: []
# No stems removed for Track00132. Skipping mix update.
# Processing track: Track00133
# Stems to remove: []
# No stems removed for Track00133. Skipping mix update.
# Processing track: Track00134
# Stems to remove: []
# No stems removed for Track00134. Skipping mix update.
# Processing track: Track00135
# Stems to remove: []
# No stems removed for Track00135. Skipping mix update.
# Processing track: Track00136
# Stems to remove: []
# No stems removed for Track00136. Skipping mix update.
# Processing track: Track00137
# Stems to remove: []
# No stems removed for Track00137. Skipping mix update.
# Processing track: Track00138
# Stems to remove: []
# No stems removed for Track00138. Skipping mix update.
# Processing track: Track00139
# Stems to remove: []
# No stems removed for Track00139. Skipping mix update.
# Processing track: Track00140
# Stems to remove: []
# No stems removed for Track00140. Skipping mix update.
# Processing track: Track00141
# Stems to remove: []
# No stems removed for Track00141. Skipping mix update.
# Processing track: Track00142
# Stems to remove: []
# No stems removed for Track00142. Skipping mix update.
# Processing track: Track00143
# Stems to remove: []
# No stems removed for Track00143. Skipping mix update.
# Processing track: Track00144
# Stems to remove: []
# No stems removed for Track00144. Skipping mix update.
# Processing track: Track00145
# Stems to remove: []
# No stems removed for Track00145. Skipping mix update.
# Processing track: Track00147
# Stems to remove: []
# No stems removed for Track00147. Skipping mix update.
# Processing track: Track00148
# Stems to remove: []
# No stems removed for Track00148. Skipping mix update.
# Processing track: Track00149
# Stems to remove: []
# No stems removed for Track00149. Skipping mix update.
# Processing track: Track00150
# Stems to remove: []
# No stems removed for Track00150. Skipping mix update.
# Processing track: Track00151
# Stems to remove: []
# No stems removed for Track00151. Skipping mix update.
# Processing track: Track00152
# Stems to remove: ['S06']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00152\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00152\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00152
# Processing track: Track00153
# Stems to remove: []
# No stems removed for Track00153. Skipping mix update.
# Processing track: Track00154
# Stems to remove: []
# No stems removed for Track00154. Skipping mix update.
# Processing track: Track00155
# Stems to remove: []
# No stems removed for Track00155. Skipping mix update.
# Processing track: Track00156
# Stems to remove: []
# No stems removed for Track00156. Skipping mix update.
# Processing track: Track00157
# Stems to remove: []
# No stems removed for Track00157. Skipping mix update.
# Processing track: Track00158
# Stems to remove: []
# No stems removed for Track00158. Skipping mix update.
# Processing track: Track00159
# Stems to remove: []
# No stems removed for Track00159. Skipping mix update.
# Processing track: Track00160
# Stems to remove: []
# No stems removed for Track00160. Skipping mix update.
# Processing track: Track00161
# Stems to remove: []
# No stems removed for Track00161. Skipping mix update.
# Processing track: Track00162
# Stems to remove: []
# No stems removed for Track00162. Skipping mix update.
# Processing track: Track00163
# Stems to remove: []
# No stems removed for Track00163. Skipping mix update.
# Processing track: Track00164
# Stems to remove: ['S10']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00164\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00164\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00164\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00164\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00164\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00164\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00164\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00164\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00164\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00164\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00164\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00164\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00164
# Processing track: Track00165
# Stems to remove: []
# No stems removed for Track00165. Skipping mix update.
# Processing track: Track00166
# Stems to remove: []
# No stems removed for Track00166. Skipping mix update.
# Processing track: Track00167
# Stems to remove: []
# No stems removed for Track00167. Skipping mix update.
# Processing track: Track00168
# Stems to remove: []
# No stems removed for Track00168. Skipping mix update.
# Processing track: Track00169
# Stems to remove: []
# No stems removed for Track00169. Skipping mix update.
# Processing track: Track00171
# Stems to remove: []
# No stems removed for Track00171. Skipping mix update.
# Processing track: Track00172
# Stems to remove: []
# No stems removed for Track00172. Skipping mix update.
# Processing track: Track00173
# Stems to remove: []
# No stems removed for Track00173. Skipping mix update.
# Processing track: Track00174
# Stems to remove: []
# No stems removed for Track00174. Skipping mix update.
# Processing track: Track00175
# Stems to remove: []
# No stems removed for Track00175. Skipping mix update.
# Processing track: Track00176
# Stems to remove: []
# No stems removed for Track00176. Skipping mix update.
# Processing track: Track00177
# Stems to remove: []
# No stems removed for Track00177. Skipping mix update.
# Processing track: Track00178
# Stems to remove: []
# No stems removed for Track00178. Skipping mix update.
# Processing track: Track00179
# Stems to remove: []
# No stems removed for Track00179. Skipping mix update.
# Processing track: Track00180
# Stems to remove: []
# No stems removed for Track00180. Skipping mix update.
# Processing track: Track00181
# Stems to remove: ['S04']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00181\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00181\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00181\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00181\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00181\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00181\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00181\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00181\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00181\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00181\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00181\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00181\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00181
# Processing track: Track00182
# Stems to remove: []
# No stems removed for Track00182. Skipping mix update.
# Processing track: Track00183
# Stems to remove: []
# No stems removed for Track00183. Skipping mix update.
# Processing track: Track00184
# Stems to remove: []
# No stems removed for Track00184. Skipping mix update.
# Processing track: Track00185
# Stems to remove: []
# No stems removed for Track00185. Skipping mix update.
# Processing track: Track00186
# Stems to remove: []
# No stems removed for Track00186. Skipping mix update.
# Processing track: Track00187
# Stems to remove: []
# No stems removed for Track00187. Skipping mix update.
# Processing track: Track00188
# Stems to remove: []
# No stems removed for Track00188. Skipping mix update.
# Processing track: Track00189
# Stems to remove: []
# No stems removed for Track00189. Skipping mix update.
# Processing track: Track00190
# Stems to remove: []
# No stems removed for Track00190. Skipping mix update.
# Processing track: Track00191
# Stems to remove: []
# No stems removed for Track00191. Skipping mix update.
# Processing track: Track00192
# Stems to remove: []
# No stems removed for Track00192. Skipping mix update.
# Processing track: Track00193
# Stems to remove: []
# No stems removed for Track00193. Skipping mix update.
# Processing track: Track00194
# Stems to remove: []
# No stems removed for Track00194. Skipping mix update.
# Processing track: Track00195
# Stems to remove: []
# No stems removed for Track00195. Skipping mix update.
# Processing track: Track00196
# Stems to remove: []
# No stems removed for Track00196. Skipping mix update.
# Processing track: Track00197
# Stems to remove: []
# No stems removed for Track00197. Skipping mix update.
# Processing track: Track00198
# Stems to remove: []
# No stems removed for Track00198. Skipping mix update.
# Processing track: Track00199
# Stems to remove: []
# No stems removed for Track00199. Skipping mix update.
# Processing track: Track00200
# Stems to remove: []
# No stems removed for Track00200. Skipping mix update.
# Processing track: Track00201
# Stems to remove: []
# No stems removed for Track00201. Skipping mix update.
# Processing track: Track00202
# Stems to remove: []
# No stems removed for Track00202. Skipping mix update.
# Processing track: Track00203
# Stems to remove: []
# No stems removed for Track00203. Skipping mix update.
# Processing track: Track00204
# Stems to remove: []
# No stems removed for Track00204. Skipping mix update.
# Processing track: Track00205
# Stems to remove: []
# No stems removed for Track00205. Skipping mix update.
# Processing track: Track00206
# Stems to remove: ['S04']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00206\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00206\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00206\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00206\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00206\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00206\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00206\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00206\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00206\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00206\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00206\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00206\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00206\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00206\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00206
# Processing track: Track00207
# Stems to remove: ['S12']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00207\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00207\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00207
# Processing track: Track00208
# Stems to remove: []
# No stems removed for Track00208. Skipping mix update.
# Processing track: Track00209
# Stems to remove: []
# No stems removed for Track00209. Skipping mix update.
# Processing track: Track00210
# Stems to remove: []
# No stems removed for Track00210. Skipping mix update.
# Processing track: Track00211
# Stems to remove: ['S03']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_train\\Track00211\\stems\\S15.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00211\stems\S15.flac
# Exporting mixed file
# Finished processing track: Track00211
# Processing track: Track00213
# Stems to remove: []
# No stems removed for Track00213. Skipping mix update.
# Processing track: Track00214
# Stems to remove: []
# No stems removed for Track00214. Skipping mix update.
# Processing track: Track00215
# Stems to remove: ['S08']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00215\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00215\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00215
# Processing track: Track00216
# Stems to remove: []
# No stems removed for Track00216. Skipping mix update.
# Processing track: Track00217
# Stems to remove: []
# No stems removed for Track00217. Skipping mix update.
# Processing track: Track00218
# Stems to remove: []
# No stems removed for Track00218. Skipping mix update.
# Processing track: Track00219
# Stems to remove: []
# No stems removed for Track00219. Skipping mix update.
# Processing track: Track00220
# Stems to remove: ['S02']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00220\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00220\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00220
# Processing track: Track00221
# Stems to remove: []
# No stems removed for Track00221. Skipping mix update.
# Processing track: Track00222
# Stems to remove: []
# No stems removed for Track00222. Skipping mix update.
# Processing track: Track00223
# Stems to remove: []
# No stems removed for Track00223. Skipping mix update.
# Processing track: Track00224
# Stems to remove: []
# No stems removed for Track00224. Skipping mix update.
# Processing track: Track00225
# Stems to remove: []
# No stems removed for Track00225. Skipping mix update.
# Processing track: Track00226
# Stems to remove: []
# No stems removed for Track00226. Skipping mix update.
# Processing track: Track00227
# Stems to remove: []
# No stems removed for Track00227. Skipping mix update.
# Processing track: Track00228
# Stems to remove: []
# No stems removed for Track00228. Skipping mix update.
# Processing track: Track00229
# Stems to remove: []
# No stems removed for Track00229. Skipping mix update.
# Processing track: Track00230
# Stems to remove: []
# No stems removed for Track00230. Skipping mix update.
# Processing track: Track00231
# Stems to remove: []
# No stems removed for Track00231. Skipping mix update.
# Processing track: Track00233
# Stems to remove: []
# No stems removed for Track00233. Skipping mix update.
# Processing track: Track00234
# Stems to remove: []
# No stems removed for Track00234. Skipping mix update.
# Processing track: Track00235
# Stems to remove: []
# No stems removed for Track00235. Skipping mix update.
# Processing track: Track00236
# Stems to remove: []
# No stems removed for Track00236. Skipping mix update.
# Processing track: Track00237
# Stems to remove: []
# No stems removed for Track00237. Skipping mix update.
# Processing track: Track00238
# Stems to remove: []
# No stems removed for Track00238. Skipping mix update.
# Processing track: Track00239
# Stems to remove: ['S03']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00239\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00239\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00239
# Processing track: Track00241
# Stems to remove: []
# No stems removed for Track00241. Skipping mix update.
# Processing track: Track00242
# Stems to remove: []
# No stems removed for Track00242. Skipping mix update.
# Processing track: Track00243
# Stems to remove: []
# No stems removed for Track00243. Skipping mix update.
# Processing track: Track00244
# Stems to remove: ['S09']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00244\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00244\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00244\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00244\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00244\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00244\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track00244
# Processing track: Track00245
# Stems to remove: []
# No stems removed for Track00245. Skipping mix update.
# Processing track: Track00246
# Stems to remove: []
# No stems removed for Track00246. Skipping mix update.
# Processing track: Track00247
# Stems to remove: []
# No stems removed for Track00247. Skipping mix update.
# Processing track: Track00248
# Stems to remove: ['S04']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00248\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00248\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00248\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00248\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00248\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00248\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00248
# Processing track: Track00249
# Stems to remove: []
# No stems removed for Track00249. Skipping mix update.
# Processing track: Track00250
# Stems to remove: []
# No stems removed for Track00250. Skipping mix update.
# Processing track: Track00252
# Stems to remove: []
# No stems removed for Track00252. Skipping mix update.
# Processing track: Track00253
# Stems to remove: []
# No stems removed for Track00253. Skipping mix update.
# Processing track: Track00254
# Stems to remove: []
# No stems removed for Track00254. Skipping mix update.
# Processing track: Track00255
# Stems to remove: []
# No stems removed for Track00255. Skipping mix update.
# Processing track: Track00257
# Stems to remove: []
# No stems removed for Track00257. Skipping mix update.
# Processing track: Track00258
# Stems to remove: []
# No stems removed for Track00258. Skipping mix update.
# Processing track: Track00259
# Stems to remove: []
# No stems removed for Track00259. Skipping mix update.
# Processing track: Track00260
# Stems to remove: []
# No stems removed for Track00260. Skipping mix update.
# Processing track: Track00261
# Stems to remove: []
# No stems removed for Track00261. Skipping mix update.
# Processing track: Track00262
# Stems to remove: ['S02']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00262\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00262\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00262\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00262\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00262\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00262\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00262\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00262\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00262\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00262\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00262\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00262\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00262
# Processing track: Track00263
# Stems to remove: ['S02']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00263\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00263\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00263\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00263\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00263\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00263\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00263\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00263\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00263\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00263\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00263\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00263\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00263
# Processing track: Track00264
# Stems to remove: []
# No stems removed for Track00264. Skipping mix update.
# Processing track: Track00265
# Stems to remove: []
# No stems removed for Track00265. Skipping mix update.
# Processing track: Track00266
# Stems to remove: []
# No stems removed for Track00266. Skipping mix update.
# Processing track: Track00267
# Stems to remove: []
# No stems removed for Track00267. Skipping mix update.
# Processing track: Track00268
# Stems to remove: []
# No stems removed for Track00268. Skipping mix update.
# Processing track: Track00269
# Stems to remove: []
# No stems removed for Track00269. Skipping mix update.
# Processing track: Track00270
# Stems to remove: []
# No stems removed for Track00270. Skipping mix update.
# Processing track: Track00271
# Stems to remove: []
# No stems removed for Track00271. Skipping mix update.
# Processing track: Track00272
# Stems to remove: []
# No stems removed for Track00272. Skipping mix update.
# Processing track: Track00273
# Stems to remove: []
# No stems removed for Track00273. Skipping mix update.
# Processing track: Track00274
# Stems to remove: []
# No stems removed for Track00274. Skipping mix update.
# Processing track: Track00275
# Stems to remove: ['S08']
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00275\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00275\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00275
# Processing track: Track00276
# Stems to remove: []
# No stems removed for Track00276. Skipping mix update.
# Processing track: Track00277
# Stems to remove: []
# No stems removed for Track00277. Skipping mix update.
# Processing track: Track00278
# Stems to remove: []
# No stems removed for Track00278. Skipping mix update.
# Processing track: Track00279
# Stems to remove: []
# No stems removed for Track00279. Skipping mix update.
# Processing track: Track00281
# Stems to remove: []
# No stems removed for Track00281. Skipping mix update.
# Processing track: Track00282
# Stems to remove: []
# No stems removed for Track00282. Skipping mix update.
# Processing track: Track00283
# Stems to remove: []
# No stems removed for Track00283. Skipping mix update.
# Processing track: Track00284
# ...
# Stems to remove: []
# No stems removed for Track01952. Skipping mix update.
# Processing track: Track01954
# Stems to remove: []
# No stems removed for Track01954. Skipping mix update.
# Processing track: Track01955
# Stems to remove: []
# No stems removed for Track01955. Skipping mix update.
# Processing track: Track01956
# Stems to remove: []
# No stems removed for Track01956. Skipping mix update.
# Processing track: Track01957
# Stems to remove: []
# No stems removed for Track01957. Skipping mix update.
# Processing track: Track01959
# Stems to remove: []
# No stems removed for Track01959. Skipping mix update.
# Processing track: Track01960
# Stems to remove: []
# No stems removed for Track01960. Skipping mix update.
# Processing track: Track01961
# Stems to remove: []
# No stems removed for Track01961. Skipping mix update.
# Processing track: Track01962
# Stems to remove: []
# No stems removed for Track01962. Skipping mix update.
# Processing track: Track01963
# Stems to remove: ['S06']
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track01963\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track01963\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track01963\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track01963\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track01963\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track01963\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track01963\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track01963\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track01963\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track01963\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track01963\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track01963\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track01963
# Processing track: Track01965
# Stems to remove: []
# No stems removed for Track01965. Skipping mix update.
# Processing track: Track01967
# Stems to remove: []
# No stems removed for Track01967. Skipping mix update.
# Processing track: Track01968
# Stems to remove: []
# No stems removed for Track01968. Skipping mix update.
# Processing track: Track01972
# Stems to remove: []
# No stems removed for Track01972. Skipping mix update.
# Processing track: Track01973
# Stems to remove: []
# No stems removed for Track01973. Skipping mix update.
# Processing track: Track01974
# Stems to remove: []
# No stems removed for Track01974. Skipping mix update.
# Processing track: Track01975
# Stems to remove: []
# No stems removed for Track01975. Skipping mix update.
# Processing track: Track01976
# Stems to remove: []
# No stems removed for Track01976. Skipping mix update.
# Processing track: Track01977
# Stems to remove: []
# No stems removed for Track01977. Skipping mix update.
# Processing track: Track01978
# Stems to remove: []
# No stems removed for Track01978. Skipping mix update.
# Processing track: Track01980
# Stems to remove: []
# No stems removed for Track01980. Skipping mix update.
# Processing track: Track01981
# Stems to remove: []
# No stems removed for Track01981. Skipping mix update.
# Processing track: Track01982
# Stems to remove: []
# No stems removed for Track01982. Skipping mix update.
# Processing track: Track01985
# Stems to remove: []
# No stems removed for Track01985. Skipping mix update.
# Processing track: Track01986
# Stems to remove: []
# No stems removed for Track01986. Skipping mix update.
# Processing track: Track01987
# Stems to remove: []
# No stems removed for Track01987. Skipping mix update.
# Processing track: Track01989
# Stems to remove: []
# No stems removed for Track01989. Skipping mix update.
# Processing track: Track01990
# Stems to remove: []
# No stems removed for Track01990. Skipping mix update.
# Processing track: Track01993
# Stems to remove: []
# No stems removed for Track01993. Skipping mix update.
# Processing track: Track01994
# Stems to remove: []
# No stems removed for Track01994. Skipping mix update.
# Processing track: Track01995
# Stems to remove: []
# No stems removed for Track01995. Skipping mix update.
# Processing track: Track01996
# Stems to remove: []
# No stems removed for Track01996. Skipping mix update.
# Processing track: Track01997
# Stems to remove: []
# No stems removed for Track01997. Skipping mix update.
# Processing track: Track01998
# Stems to remove: []
# No stems removed for Track01998. Skipping mix update.
# Processing track: Track02000
# Stems to remove: []
# No stems removed for Track02000. Skipping mix update.
# Processing track: Track02001
# Stems to remove: []
# No stems removed for Track02001. Skipping mix update.
# Processing track: Track02002
# Stems to remove: []
# No stems removed for Track02002. Skipping mix update.
# Processing track: Track02003
# Stems to remove: []
# No stems removed for Track02003. Skipping mix update.
# Processing track: Track02004
# Stems to remove: []
# No stems removed for Track02004. Skipping mix update.
# Processing track: Track02005
# Stems to remove: []
# No stems removed for Track02005. Skipping mix update.
# Processing track: Track02007
# Stems to remove: []
# No stems removed for Track02007. Skipping mix update.
# Processing track: Track02008
# Stems to remove: []
# No stems removed for Track02008. Skipping mix update.
# Processing track: Track02010
# Stems to remove: []
# No stems removed for Track02010. Skipping mix update.
# Processing track: Track02013
# Stems to remove: []
# No stems removed for Track02013. Skipping mix update.
# Processing track: Track02014
# Stems to remove: []
# No stems removed for Track02014. Skipping mix update.
# Processing track: Track02016
# Stems to remove: []
# No stems removed for Track02016. Skipping mix update.
# Processing track: Track02017
# Stems to remove: []
# No stems removed for Track02017. Skipping mix update.
# Processing track: Track02018
# Stems to remove: []
# No stems removed for Track02018. Skipping mix update.
# Processing track: Track02019
# Stems to remove: []
# No stems removed for Track02019. Skipping mix update.
# Processing track: Track02020
# Stems to remove: ['S10']
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02020\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02020\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track02020
# Processing track: Track02023
# Stems to remove: []
# No stems removed for Track02023. Skipping mix update.
# Processing track: Track02024
# Stems to remove: []
# No stems removed for Track02024. Skipping mix update.
# Processing track: Track02026
# Stems to remove: []
# No stems removed for Track02026. Skipping mix update.
# Processing track: Track02029
# Stems to remove: []
# No stems removed for Track02029. Skipping mix update.
# Processing track: Track02030
# Stems to remove: []
# No stems removed for Track02030. Skipping mix update.
# Processing track: Track02031
# Stems to remove: []
# No stems removed for Track02031. Skipping mix update.
# Processing track: Track02032
# Stems to remove: []
# No stems removed for Track02032. Skipping mix update.
# Processing track: Track02036
# Stems to remove: []
# No stems removed for Track02036. Skipping mix update.
# Processing track: Track02037
# Stems to remove: []
# No stems removed for Track02037. Skipping mix update.
# Processing track: Track02038
# Stems to remove: []
# No stems removed for Track02038. Skipping mix update.
# Processing track: Track02040
# Stems to remove: []
# No stems removed for Track02040. Skipping mix update.
# Processing track: Track02042
# Stems to remove: []
# No stems removed for Track02042. Skipping mix update.
# Processing track: Track02044
# Stems to remove: ['S01']
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_test\\Track02044\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02044\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track02044
# Processing track: Track02045
# Stems to remove: []
# No stems removed for Track02045. Skipping mix update.
# Processing track: Track02046
# Stems to remove: ['S07']
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_test\\Track02046\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02046\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track02046
# Processing track: Track02047
# Stems to remove: []
# No stems removed for Track02047. Skipping mix update.
# Processing track: Track02048
# Stems to remove: []
# No stems removed for Track02048. Skipping mix update.
# Processing track: Track02049
# Stems to remove: []
# No stems removed for Track02049. Skipping mix update.
# Processing track: Track02050
# Stems to remove: []
# No stems removed for Track02050. Skipping mix update.
# Processing track: Track02051
# Stems to remove: []
# No stems removed for Track02051. Skipping mix update.
# Processing track: Track02052
# Stems to remove: []
# No stems removed for Track02052. Skipping mix update.
# Processing track: Track02053
# Stems to remove: []
# No stems removed for Track02053. Skipping mix update.
# Processing track: Track02054
# Stems to remove: []
# No stems removed for Track02054. Skipping mix update.
# Processing track: Track02056
# Stems to remove: []
# No stems removed for Track02056. Skipping mix update.
# Processing track: Track02061
# Stems to remove: []
# No stems removed for Track02061. Skipping mix update.
# Processing track: Track02062
# Stems to remove: []
# No stems removed for Track02062. Skipping mix update.
# Processing track: Track02063
# Stems to remove: []
# No stems removed for Track02063. Skipping mix update.
# Processing track: Track02064
# Stems to remove: []
# No stems removed for Track02064. Skipping mix update.
# Processing track: Track02067
# Stems to remove: []
# No stems removed for Track02067. Skipping mix update.
# Processing track: Track02069
# Stems to remove: []
# No stems removed for Track02069. Skipping mix update.
# Processing track: Track02070
# Stems to remove: ['S07']
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track02070
# Processing track: Track02074
# Stems to remove: []
# No stems removed for Track02074. Skipping mix update.
# Processing track: Track02079
# Stems to remove: []
# No stems removed for Track02079. Skipping mix update.
# Processing track: Track02081
# Stems to remove: []
# No stems removed for Track02081. Skipping mix update.
# Processing track: Track02082
# Stems to remove: ['S04']
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track02082
# Processing track: Track02083
# Stems to remove: []
# No stems removed for Track02083. Skipping mix update.
# Processing track: Track02084
# Stems to remove: []
# No stems removed for Track02084. Skipping mix update.
# Processing track: Track02086
# Stems to remove: []
# No stems removed for Track02086. Skipping mix update.
# Processing track: Track02087
# Stems to remove: []
# No stems removed for Track02087. Skipping mix update.
# Processing track: Track02088
# Stems to remove: []
# No stems removed for Track02088. Skipping mix update.
# Processing track: Track02090
# Stems to remove: []
# No stems removed for Track02090. Skipping mix update.
# Processing track: Track02092
# Stems to remove: []
# No stems removed for Track02092. Skipping mix update.
# Processing track: Track02093
# Stems to remove: []
# No stems removed for Track02093. Skipping mix update.
# Processing track: Track02094
# Stems to remove: []
# No stems removed for Track02094. Skipping mix update.
# Processing track: Track02095
# Stems to remove: []
# No stems removed for Track02095. Skipping mix update.
# Processing track: Track02096
# Stems to remove: []
# No stems removed for Track02096. Skipping mix update.
# Processing track: Track02098
# Stems to remove: []
# No stems removed for Track02098. Skipping mix update.
