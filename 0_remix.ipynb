# %%
import os
import yaml
from pydub import AudioSegment
import time

program_nums_to_remove = {46, 47, 52, 53, 54, 55, 69, 70, 76, 77, 78, 79}
plugin_names_to_remove = {"harpsichord.nkm", "scarbee_a_200.nkm", "scarbee_clavinet_full.nkm", "scarbee_mark_I.nkm", "scarbee_pianet.nkm", "wurly_ep.nkm"}

# Define the sets to process
data_sets = [
    "slakh2100_flac_redux/reduced_train",
    "slakh2100_flac_redux/reduced_validation",
    "slakh2100_flac_redux/reduced_test",
]

for DIR_PATH in data_sets:
    print(f"\nProcessing data set: {DIR_PATH}")  # Indicate current dataset

    # Iterate through each track folder
    for track in os.listdir(DIR_PATH):
        track_path = os.path.join(DIR_PATH, track)
        metadata_path = os.path.join(track_path, "metadata.yaml")
        stems_path = os.path.join(track_path, "stems")
        mix_path = os.path.join(track_path, "mix.flac")

        if not os.path.isdir(track_path) or not os.path.exists(metadata_path):
            continue

        print(f"Processing track: {track}")

        with open(metadata_path, "r") as f:
            metadata = yaml.safe_load(f)

        if "stems" not in metadata:
            continue

        stems_to_remove = []
        for stem_id, stem_data in metadata["stems"].items():
            inst_class = stem_data.get("inst_class", "")
            program_num = stem_data.get("program_num", None)
            plugin_name = stem_data.get("plugin_name", None)

            if (inst_class in {"Chromatic Percussion", "Organ", "Synth Lead", "Synth Pad", "Sound Effects", "Ethnic", "Percussive", "Sound effects", "Brass", "Reed", "Pipe"} or
                program_num in program_nums_to_remove or
                (plugin_name and plugin_name in plugin_names_to_remove)):
                stems_to_remove.append(stem_id)

        print(f"Stems to remove: {stems_to_remove}")

        if not stems_to_remove:
            print(f"No stems removed for {track}. Skipping mix update.")
            continue

        for stem_id in stems_to_remove:
            stem_file = os.path.join(stems_path, f"{stem_id}.flac")
            if os.path.exists(stem_file):
                print(f"Removing {stem_file}")
                os.remove(stem_file)
            del metadata["stems"][stem_id]

        with open(metadata_path, "w") as f:
            yaml.dump(metadata, f, default_flow_style=False)

        remaining_stems = [os.path.join(stems_path, f"{stem_id}.flac") for stem_id in metadata["stems"] if os.path.exists(os.path.join(stems_path, f"{stem_id}.flac"))]
        print(f"Remaining stems: {remaining_stems}")

        if remaining_stems:
            mixed_audio = None
            for stem_file in remaining_stems:
                print(f"Mixing {stem_file}")
                audio = AudioSegment.from_file(stem_file)
                mixed_audio = audio if mixed_audio is None else mixed_audio.overlay(audio)
            print("Exporting mixed file")
            mixed_audio.export(mix_path, format="flac")
        else:
            print(f"Deleting track folder: {track_path}")
            for root, dirs, files in os.walk(track_path, topdown=False):
                for file in files:
                    file_path = os.path.join(root, file)
                    print(f"Deleting file: {file_path}")
                    os.remove(file_path)
                for dir in dirs:
                    dir_path = os.path.join(root, dir)
                    print(f"Deleting dir: {dir_path}")
                    os.rmdir(dir_path)
            print(f"Removing empty track folder: {track_path}")
            os.rmdir(track_path)

        print(f"Finished processing track: {track}")
        time.sleep(0.1)
# Out:
# Processing data set: slakh2100_flac_redux/reduced_train
# Processing track: Track00001
# Stems to remove: []
# No stems removed for Track00001. Skipping mix update.
# Processing track: Track00002
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00002\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00002\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00002\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00002
# Processing track: Track00003
# Stems to remove: []
# No stems removed for Track00003. Skipping mix update.
# Processing track: Track00004
# Stems to remove: []
# No stems removed for Track00004. Skipping mix update.
# Processing track: Track00005
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00005\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00005\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00005\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00005\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00005\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00005\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00005\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00005\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00005\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00005\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00005\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00005\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00005\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00005\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00005\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00005
# Processing track: Track00006
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00006\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00006\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00006\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track00006
# Processing track: Track00007
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track00007\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00007\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00007\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00007
# Processing track: Track00008
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00008\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00008\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00008\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00008\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00008\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00008\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00008\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00008\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00008\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00008\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00008\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track00008
# Processing track: Track00009
# Stems to remove: []
# No stems removed for Track00009. Skipping mix update.
# Processing track: Track00010
# Stems to remove: []
# No stems removed for Track00010. Skipping mix update.
# Processing track: Track00011
# Stems to remove: []
# No stems removed for Track00011. Skipping mix update.
# Processing track: Track00012
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00012\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00012\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00012\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00012
# Processing track: Track00013
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track00013\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00013\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00013\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00013
# Processing track: Track00014
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_train\Track00014\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00014\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00014\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00014
# Processing track: Track00015
# Stems to remove: []
# No stems removed for Track00015. Skipping mix update.
# Processing track: Track00016
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_train\Track00016\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00016\\stems\\S15.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00016\stems\S15.flac
# Exporting mixed file
# Finished processing track: Track00016
# Processing track: Track00017
# Stems to remove: []
# No stems removed for Track00017. Skipping mix update.
# Processing track: Track00018
# Stems to remove: []
# No stems removed for Track00018. Skipping mix update.
# Processing track: Track00019
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00019\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00019\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00019\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00019
# Processing track: Track00020
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00020\stems\S06.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00020\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00020\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00020
# Processing track: Track00021
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track00021\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00021\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00021\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00021
# Processing track: Track00022
# Stems to remove: ['S11', 'S12', 'S17']
# Removing slakh2100_flac_redux/reduced_train\Track00022\stems\S11.flac
# Removing slakh2100_flac_redux/reduced_train\Track00022\stems\S12.flac
# Removing slakh2100_flac_redux/reduced_train\Track00022\stems\S17.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S13.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S14.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S15.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S16.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S18.flac', 'slakh2100_flac_redux/reduced_train\\Track00022\\stems\\S19.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S13.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S14.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S15.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S16.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S18.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00022\stems\S19.flac
# Exporting mixed file
# Finished processing track: Track00022
# Processing track: Track00023
# Stems to remove: []
# No stems removed for Track00023. Skipping mix update.
# Processing track: Track00024
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00024\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00024\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00024\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00024
# Processing track: Track00025
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00025\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00025\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00025\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00025
# Processing track: Track00026
# Stems to remove: []
# No stems removed for Track00026. Skipping mix update.
# Processing track: Track00027
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_train\Track00027\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00027\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00027\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00027
# Processing track: Track00028
# Stems to remove: ['S01', 'S12']
# Removing slakh2100_flac_redux/reduced_train\Track00028\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_train\Track00028\stems\S12.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00028\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00028\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00028
# Processing track: Track00029
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00029\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00029\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00029\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00029\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00029\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00029\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00029\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00029\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00029\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00029\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00029\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00029\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00029\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00029\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00029\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track00029
# Processing track: Track00030
# Stems to remove: ['S02', 'S03']
# Removing slakh2100_flac_redux/reduced_train\Track00030\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_train\Track00030\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00030\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00030\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track00030
# Processing track: Track00031
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track00031\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00031\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00031\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00031\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00031\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00031\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00031\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00031\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00031\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00031\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00031\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00031
# Processing track: Track00032
# Stems to remove: []
# No stems removed for Track00032. Skipping mix update.
# Processing track: Track00033
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00033\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00033\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00033\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00033
# Processing track: Track00034
# Stems to remove: ['S01', 'S02']
# Removing slakh2100_flac_redux/reduced_train\Track00034\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_train\Track00034\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00034\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00034\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00034
# Processing track: Track00035
# Stems to remove: []
# No stems removed for Track00035. Skipping mix update.
# Processing track: Track00036
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00036\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00036\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00036\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00036\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00036\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00036\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00036\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00036\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00036\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00036\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00036\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00036\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00036\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00036
# Processing track: Track00037
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_train\Track00037\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00037\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00037\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00037
# Processing track: Track00038
# Stems to remove: ['S11']
# Removing slakh2100_flac_redux/reduced_train\Track00038\stems\S11.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00038\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00038\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00038
# Processing track: Track00039
# Stems to remove: []
# No stems removed for Track00039. Skipping mix update.
# Processing track: Track00040
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_train\Track00040\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00040\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00040\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00040
# Processing track: Track00041
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00041\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00041\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00041\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00041
# Processing track: Track00042
# Stems to remove: []
# No stems removed for Track00042. Skipping mix update.
# Processing track: Track00043
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00043\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00043\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00043\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00043\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00043\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00043\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00043\\stems\\S10.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00043\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00043\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00043\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00043\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00043\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00043\stems\S10.flac
# Exporting mixed file
# Finished processing track: Track00043
# Processing track: Track00044
# Stems to remove: ['S09', 'S11', 'S13']
# Removing slakh2100_flac_redux/reduced_train\Track00044\stems\S09.flac
# Removing slakh2100_flac_redux/reduced_train\Track00044\stems\S11.flac
# Removing slakh2100_flac_redux/reduced_train\Track00044\stems\S13.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00044\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00044\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track00044
# Processing track: Track00045
# Stems to remove: ['S04', 'S05']
# Removing slakh2100_flac_redux/reduced_train\Track00045\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_train\Track00045\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00045\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00045\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00045\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00045\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00045\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00045\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00045\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00045\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00045\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00045\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00045\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00045\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00045\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00045\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00045
# Processing track: Track00046
# Stems to remove: []
# No stems removed for Track00046. Skipping mix update.
# Processing track: Track00047
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_train\Track00047\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00047\\stems\\S03.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00047\stems\S03.flac
# Exporting mixed file
# Finished processing track: Track00047
# Processing track: Track00048
# Stems to remove: []
# No stems removed for Track00048. Skipping mix update.
# Processing track: Track00050
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00050\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00050\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00050\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00050
# Processing track: Track00051
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00051\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00051\\stems\\S06.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00051\stems\S06.flac
# Exporting mixed file
# Finished processing track: Track00051
# Processing track: Track00052
# Stems to remove: ['S05', 'S08']
# Removing slakh2100_flac_redux/reduced_train\Track00052\stems\S05.flac
# Removing slakh2100_flac_redux/reduced_train\Track00052\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00052\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00052\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00052\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00052\\stems\\S03.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00052\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00052\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00052\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00052\stems\S03.flac
# Exporting mixed file
# Finished processing track: Track00052
# Processing track: Track00053
# Stems to remove: []
# No stems removed for Track00053. Skipping mix update.
# Processing track: Track00054
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00054\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S12.flac', 'slakh2100_flac_redux/reduced_train\\Track00054\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00054\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track00054
# Processing track: Track00055
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00055\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00055\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00055\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track00055
# Processing track: Track00056
# Stems to remove: ['S03', 'S10']
# Removing slakh2100_flac_redux/reduced_train\Track00056\stems\S03.flac
# Removing slakh2100_flac_redux/reduced_train\Track00056\stems\S10.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00056\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00056\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00056
# Processing track: Track00057
# Stems to remove: ['S05']
# Removing slakh2100_flac_redux/reduced_train\Track00057\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00057\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00057\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00057
# Processing track: Track00058
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_train\Track00058\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00058\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00058\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00058
# Processing track: Track00059
# Stems to remove: ['S08']
# Removing slakh2100_flac_redux/reduced_train\Track00059\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_train\\Track00059\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00059\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track00059
# Processing track: Track00060
# Stems to remove: []
# No stems removed for Track00060. Skipping mix update.
# Processing track: Track00061
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00061\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00061\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00061\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00061
# Processing track: Track00062
# Stems to remove: []
# No stems removed for Track00062. Skipping mix update.
# Processing track: Track00063
# Stems to remove: ['S02', 'S07']
# Removing slakh2100_flac_redux/reduced_train\Track00063\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_train\Track00063\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00063\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_train\\Track00063\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00063\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_train\\Track00063\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00063\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00063\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00063\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00063\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track00063
# Processing track: Track00064
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_train\Track00064\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_train\\Track00064\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_train\Track00064\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track00064
# Processing track: Track00065
# Stems to remove: []
# No stems removed for Track00065. Skipping mix update.
# Processing track: Track00066
# Stems to remove: []
# No stems removed for Track00066. Skipping mix update.
# Processing track: Track00067
# Stems to remove: ['S06']
# Removing slakh2100_flac_redux/reduced_train\Track00067\stems\S06.flac
# ...
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S12.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S16.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02064\stems\S17.flac
# Exporting mixed file
# Finished processing track: Track02064
# Processing track: Track02067
# Stems to remove: ['S02', 'S10']
# Removing slakh2100_flac_redux/reduced_test\Track02067\stems\S02.flac
# Removing slakh2100_flac_redux/reduced_test\Track02067\stems\S10.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02067\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02067\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02067\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02067\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02067\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02067\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02067\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02067\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02067\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02067\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02067\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02067\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02067\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02067\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track02067
# Processing track: Track02069
# Stems to remove: ['S00', 'S01']
# Removing slakh2100_flac_redux/reduced_test\Track02069\stems\S00.flac
# Removing slakh2100_flac_redux/reduced_test\Track02069\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S11.flac', 'slakh2100_flac_redux/reduced_test\\Track02069\\stems\\S14.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S11.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02069\stems\S14.flac
# Exporting mixed file
# Finished processing track: Track02069
# Processing track: Track02070
# Stems to remove: ['S00']
# Removing slakh2100_flac_redux/reduced_test\Track02070\stems\S00.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02070\\stems\\S09.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02070\stems\S09.flac
# Exporting mixed file
# Finished processing track: Track02070
# Processing track: Track02074
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_test\Track02074\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02074\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02074\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02074\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02074\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02074\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02074\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02074\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02074\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02074\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02074\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02074\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02074\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track02074
# Processing track: Track02079
# Stems to remove: ['S01', 'S08']
# Removing slakh2100_flac_redux/reduced_test\Track02079\stems\S01.flac
# Removing slakh2100_flac_redux/reduced_test\Track02079\stems\S08.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02079\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02079\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02079\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02079\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_test\\Track02079\\stems\\S10.flac', 'slakh2100_flac_redux/reduced_test\\Track02079\\stems\\S13.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02079\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02079\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02079\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02079\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02079\stems\S10.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02079\stems\S13.flac
# Exporting mixed file
# Finished processing track: Track02079
# Processing track: Track02081
# Stems to remove: ['S04']
# Removing slakh2100_flac_redux/reduced_test\Track02081\stems\S04.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02081\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02081\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track02081
# Processing track: Track02082
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_test\Track02082\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02082\\stems\\S08.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02082\stems\S08.flac
# Exporting mixed file
# Finished processing track: Track02082
# Processing track: Track02083
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_test\Track02083\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02083\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02083\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02083\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02083\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02083\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02083\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02083\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02083\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02083\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02083\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02083\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02083\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track02083
# Processing track: Track02084
# Stems to remove: ['S01']
# Removing slakh2100_flac_redux/reduced_test\Track02084\stems\S01.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02084\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02084\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02084\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02084\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02084\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02084\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02084\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02084\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02084\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02084\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track02084
# Processing track: Track02086
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_test\Track02086\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02086\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02086\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02086\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02086\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02086\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02086\\stems\\S07.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02086\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02086\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02086\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02086\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02086\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02086\stems\S07.flac
# Exporting mixed file
# Finished processing track: Track02086
# Processing track: Track02087
# Stems to remove: []
# No stems removed for Track02087. Skipping mix update.
# Processing track: Track02088
# Stems to remove: []
# No stems removed for Track02088. Skipping mix update.
# Processing track: Track02090
# Stems to remove: ['S07']
# Removing slakh2100_flac_redux/reduced_test\Track02090\stems\S07.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S09.flac', 'slakh2100_flac_redux/reduced_test\\Track02090\\stems\\S11.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S09.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02090\stems\S11.flac
# Exporting mixed file
# Finished processing track: Track02090
# Processing track: Track02092
# Stems to remove: []
# No stems removed for Track02092. Skipping mix update.
# Processing track: Track02093
# Stems to remove: []
# No stems removed for Track02093. Skipping mix update.
# Processing track: Track02094
# Stems to remove: ['S03']
# Removing slakh2100_flac_redux/reduced_test\Track02094\stems\S03.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S05.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S06.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S07.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S08.flac', 'slakh2100_flac_redux/reduced_test\\Track02094\\stems\\S12.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S05.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S06.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S07.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S08.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02094\stems\S12.flac
# Exporting mixed file
# Finished processing track: Track02094
# Processing track: Track02095
# Stems to remove: []
# No stems removed for Track02095. Skipping mix update.
# Processing track: Track02096
# Stems to remove: ['S02']
# Removing slakh2100_flac_redux/reduced_test\Track02096\stems\S02.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02096\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02096\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02096\\stems\\S03.flac', 'slakh2100_flac_redux/reduced_test\\Track02096\\stems\\S04.flac', 'slakh2100_flac_redux/reduced_test\\Track02096\\stems\\S05.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02096\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02096\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02096\stems\S03.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02096\stems\S04.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02096\stems\S05.flac
# Exporting mixed file
# Finished processing track: Track02096
# Processing track: Track02098
# Stems to remove: ['S04', 'S05']
# Removing slakh2100_flac_redux/reduced_test\Track02098\stems\S04.flac
# Removing slakh2100_flac_redux/reduced_test\Track02098\stems\S05.flac
# Remaining stems: ['slakh2100_flac_redux/reduced_test\\Track02098\\stems\\S00.flac', 'slakh2100_flac_redux/reduced_test\\Track02098\\stems\\S01.flac', 'slakh2100_flac_redux/reduced_test\\Track02098\\stems\\S02.flac', 'slakh2100_flac_redux/reduced_test\\Track02098\\stems\\S03.flac']
# Mixing slakh2100_flac_redux/reduced_test\Track02098\stems\S00.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02098\stems\S01.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02098\stems\S02.flac
# Mixing slakh2100_flac_redux/reduced_test\Track02098\stems\S03.flac
# Exporting mixed file
# Finished processing track: Track02098
