# %%
import os
import yaml
import shutil
from pydub import AudioSegment

# Define source and target directories
DIR_PATH = "slakh2100_flac_redux/reduced_train"
OUTPUT_DIR = "slakh2100_flac_redux/reduced_isolated"
N = 10  # Number of tracks per class

# Target instrument classes and their row indices
TARGET_CLASSES = {"Piano": 0, "Guitar": 1, "Bass": 2, "Strings": 3, "Drums": 4}

# Dictionary to store selected tracks per class
selected_tracks = {cls: [] for cls in TARGET_CLASSES}
used_tracks = set()  # Set to track already assigned tracks

# Iterate through each track folder
for track in os.listdir(DIR_PATH):
    track_path = os.path.join(DIR_PATH, track)
    metadata_path = os.path.join(track_path, "metadata.yaml")
    stems_path = os.path.join(track_path, "stems")
    
    if not os.path.isdir(track_path) or not os.path.exists(metadata_path):
        continue  
    
    with open(metadata_path, "r") as f:
        metadata = yaml.safe_load(f)
    
    if "stems" not in metadata:
        continue  
    
    # Identify instrument classes present in this track
    track_classes = {}
    for stem_id, stem_data in metadata["stems"].items():
        inst_class = stem_data.get("inst_class", "")
        if inst_class in TARGET_CLASSES:
            track_classes[inst_class] = stem_id
    
    # Skip if track is already assigned
    if track in used_tracks:
        continue
    
    # Add track to the first available class and mark it as used
    for inst_class, stem_id in track_classes.items():
        if len(selected_tracks[inst_class]) < N:
            stem_file = os.path.join(stems_path, f"{stem_id}.flac")
            
            if os.path.exists(stem_file):
                selected_tracks[inst_class].append(track)
                used_tracks.add(track)
                
                # Create track directory directly in reduced_isolated/
                target_track_dir = os.path.join(OUTPUT_DIR, track)
                os.makedirs(target_track_dir, exist_ok=True)
                
                # Create stem directory
                target_stem_dir = os.path.join(target_track_dir, "stems")
                os.makedirs(target_stem_dir, exist_ok=True)
                
                # Copy and rename the stem file as mix.flac
                target_mix_path = os.path.join(target_track_dir, "mix.flac")
                shutil.copy(stem_file, target_mix_path)
                print(f"Copied {stem_file} to {target_mix_path}")
                
                # Copy the original stem file into stem/ directory
                target_stem_path = os.path.join(target_stem_dir, f"{stem_id}.flac")
                shutil.copy(stem_file, target_stem_path)
                print(f"Copied {stem_file} to {target_stem_path}")
                
                # Copy metadata file
                target_metadata_path = os.path.join(target_track_dir, "metadata.yaml")
                with open(metadata_path, "r") as f:
                    metadata = yaml.safe_load(f)
                
                # Modify metadata to keep only the relevant stem
                metadata["stems"] = {stem_id: metadata["stems"][stem_id]}
                with open(target_metadata_path, "w") as f:
                    yaml.dump(metadata, f, default_flow_style=False)
                print(f"Updated metadata file at {target_metadata_path}")
            break
    
    # Stop early if all classes have enough tracks
    if all(len(v) >= N for v in selected_tracks.values()):
        break

# Print selected tracks
for inst_class, tracks in selected_tracks.items():
    print(f"{inst_class} ({len(tracks)} tracks):")
    for track in tracks:
        print(f"  - {track}")
    print()
# Out:
# Copied slakh2100_flac_redux/reduced_train\Track00001\stems\S08.flac to slakh2100_flac_redux/reduced_isolated\Track00001\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00001\stems\S08.flac to slakh2100_flac_redux/reduced_isolated\Track00001\stems\S08.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00001\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00002\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00002\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00002\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00002\stems\S01.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00002\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00003\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00003\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00003\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00003\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00003\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00004\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00004\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00004\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00004\stems\S01.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00004\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00005\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00005\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00005\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00005\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00005\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00006\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00006\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00006\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00006\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00006\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00007\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00007\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00007\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00007\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00007\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00008\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00008\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00008\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00008\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00008\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00009\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00009\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00009\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00009\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00009\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00010\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00010\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00010\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00010\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00010\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00011\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00011\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00011\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00011\stems\S01.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00011\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00012\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00012\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00012\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00012\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00012\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00013\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00013\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00013\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00013\stems\S01.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00013\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00014\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00014\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00014\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00014\stems\S01.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00014\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00016\stems\S10.flac to slakh2100_flac_redux/reduced_isolated\Track00016\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00016\stems\S10.flac to slakh2100_flac_redux/reduced_isolated\Track00016\stems\S10.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00016\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00017\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00017\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00017\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00017\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00017\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00018\stems\S09.flac to slakh2100_flac_redux/reduced_isolated\Track00018\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00018\stems\S09.flac to slakh2100_flac_redux/reduced_isolated\Track00018\stems\S09.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00018\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00019\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00019\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00019\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00019\stems\S12.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00019\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00020\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00020\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00020\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00020\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00020\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00022\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00022\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00022\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00022\stems\S07.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00022\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00023\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00023\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00023\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00023\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00023\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00024\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00024\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00024\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00024\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00024\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00025\stems\S04.flac to slakh2100_flac_redux/reduced_isolated\Track00025\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00025\stems\S04.flac to slakh2100_flac_redux/reduced_isolated\Track00025\stems\S04.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00025\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00026\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00026\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00026\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00026\stems\S12.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00026\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00027\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00027\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00027\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00027\stems\S01.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00027\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00028\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00028\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00028\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00028\stems\S12.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00028\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00030\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00030\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00030\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00030\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00030\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00031\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00031\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00031\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00031\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00031\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00032\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00032\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00032\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00032\stems\S05.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00032\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00034\stems\S02.flac to slakh2100_flac_redux/reduced_isolated\Track00034\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00034\stems\S02.flac to slakh2100_flac_redux/reduced_isolated\Track00034\stems\S02.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00034\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00035\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00035\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00035\stems\S00.flac to slakh2100_flac_redux/reduced_isolated\Track00035\stems\S00.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00035\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00036\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00036\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00036\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00036\stems\S05.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00036\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00037\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00037\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00037\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00037\stems\S07.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00037\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00038\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00038\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00038\stems\S12.flac to slakh2100_flac_redux/reduced_isolated\Track00038\stems\S12.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00038\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00039\stems\S03.flac to slakh2100_flac_redux/reduced_isolated\Track00039\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00039\stems\S03.flac to slakh2100_flac_redux/reduced_isolated\Track00039\stems\S03.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00039\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00040\stems\S06.flac to slakh2100_flac_redux/reduced_isolated\Track00040\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00040\stems\S06.flac to slakh2100_flac_redux/reduced_isolated\Track00040\stems\S06.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00040\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00041\stems\S04.flac to slakh2100_flac_redux/reduced_isolated\Track00041\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00041\stems\S04.flac to slakh2100_flac_redux/reduced_isolated\Track00041\stems\S04.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00041\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00042\stems\S11.flac to slakh2100_flac_redux/reduced_isolated\Track00042\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00042\stems\S11.flac to slakh2100_flac_redux/reduced_isolated\Track00042\stems\S11.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00042\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00043\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00043\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00043\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00043\stems\S07.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00043\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00044\stems\S14.flac to slakh2100_flac_redux/reduced_isolated\Track00044\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00044\stems\S14.flac to slakh2100_flac_redux/reduced_isolated\Track00044\stems\S14.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00044\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00045\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00045\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00045\stems\S01.flac to slakh2100_flac_redux/reduced_isolated\Track00045\stems\S01.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00045\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00046\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00046\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00046\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00046\stems\S05.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00046\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00048\stems\S18.flac to slakh2100_flac_redux/reduced_isolated\Track00048\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00048\stems\S18.flac to slakh2100_flac_redux/reduced_isolated\Track00048\stems\S18.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00048\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00054\stems\S14.flac to slakh2100_flac_redux/reduced_isolated\Track00054\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00054\stems\S14.flac to slakh2100_flac_redux/reduced_isolated\Track00054\stems\S14.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00054\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00065\stems\S02.flac to slakh2100_flac_redux/reduced_isolated\Track00065\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00065\stems\S02.flac to slakh2100_flac_redux/reduced_isolated\Track00065\stems\S02.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00065\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00068\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00068\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00068\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00068\stems\S07.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00068\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00069\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00069\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00069\stems\S07.flac to slakh2100_flac_redux/reduced_isolated\Track00069\stems\S07.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00069\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00085\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00085\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00085\stems\S05.flac to slakh2100_flac_redux/reduced_isolated\Track00085\stems\S05.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00085\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00090\stems\S08.flac to slakh2100_flac_redux/reduced_isolated\Track00090\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00090\stems\S08.flac to slakh2100_flac_redux/reduced_isolated\Track00090\stems\S08.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00090\metadata.yaml
# Copied slakh2100_flac_redux/reduced_train\Track00100\stems\S04.flac to slakh2100_flac_redux/reduced_isolated\Track00100\mix.flac
# Copied slakh2100_flac_redux/reduced_train\Track00100\stems\S04.flac to slakh2100_flac_redux/reduced_isolated\Track00100\stems\S04.flac
# Updated metadata file at slakh2100_flac_redux/reduced_isolated\Track00100\metadata.yaml
# Piano (10 tracks):
#   - Track00003
#   - Track00009
#   - Track00016
#   - Track00018
#   - Track00019
#   - Track00023
#   - Track00025
#   - Track00028
#   - Track00034
#   - Track00035
#
# Guitar (10 tracks):
#   - Track00001
#   - Track00026
#   - Track00032
#   - Track00036
#   - Track00037
#   - Track00038
#   - Track00042
#   - Track00044
#   - Track00045
#   - Track00046
#
# Bass (10 tracks):
#   - Track00002
#   - Track00004
#   - Track00008
#   - Track00010
#   - Track00011
#   - Track00013
#   - Track00014
#   - Track00039
#   - Track00040
#   - Track00043
#
# Strings (10 tracks):
#   - Track00022
#   - Track00041
#   - Track00048
#   - Track00054
#   - Track00065
#   - Track00068
#   - Track00069
#   - Track00085
#   - Track00090
#   - Track00100
#
# Drums (10 tracks):
#   - Track00005
#   - Track00006
#   - Track00007
#   - Track00012
#   - Track00017
#   - Track00020
#   - Track00024
#   - Track00027
#   - Track00030
#   - Track00031
