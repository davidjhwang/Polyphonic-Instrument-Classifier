# %%
import os
import numpy as np
import tensorflow as tf
import torch
import torchaudio
import torchaudio.functional as F
import torchaudio.transforms as T
import librosa
from collections import defaultdict

# %%
SAMPLE_RATE = 44100
DURATION = 1.0  # seconds per segment
STEP_SIZE = 0.5  # seconds per step (use < DURATION for overlap)
N_MELS = 128
HOP_LENGTH = 1024
N_FFT = 2048

# %%
MODEL_PATH = "classifiers/instrument_classifier.tflite"
AUDIO_PATH = "slakh2100_flac_redux/reduced_test/Track01876/mix.flac"
INSTRUMENTS = ['Piano', 'Guitar', 'Bass', 'Strings', 'Drums']
CLASS_THRESHOLDS = np.array([0.5, 0.6, 0.5, 0.3, 0.5])

# %%
interpreter = tf.lite.Interpreter(model_path=MODEL_PATH)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
def generate_mel_spect_gpu(audio_path):
    """
    Loads audio using torchaudio, resamples and normalizes it,
    and generates mel spectrograms on the GPU.
    """
    # Load with torchaudio (auto handles most formats)
    waveform, sr = torchaudio.load(audio_path)  # shape: [channels, samples]

    # Convert to mono if needed
    if waveform.shape[0] > 1:
        waveform = torch.mean(waveform, dim=0, keepdim=True)

    # Resample if sample rate doesn't match
    if sr != SAMPLE_RATE:
        resampler = T.Resample(orig_freq=sr, new_freq=SAMPLE_RATE)
        waveform = resampler(waveform)

    waveform = waveform.squeeze()  # shape: [samples]
    waveform = waveform.to(torch.float32).to("cuda")

    segment_len = int(DURATION * SAMPLE_RATE)
    step_len = int(STEP_SIZE * SAMPLE_RATE)

    # Hann window and mel filterbank (cached)
    hann_window = torch.hann_window(N_FFT, device="cuda")
    mel_filters = F.melscale_fbanks(
        n_freqs=N_FFT // 2 + 1,
        f_min=0,
        f_max=16000,
        n_mels=N_MELS,
        sample_rate=SAMPLE_RATE,
        norm=None,
        mel_scale="htk",
    ).T.to("cuda")

    mel_spects = []

    for start in range(0, waveform.shape[0] - segment_len + 1, step_len):
        segment = waveform[start:start + segment_len]

        # Normalize to [-1, 1]
        if torch.max(torch.abs(segment)) > 0:
            segment = segment / torch.max(torch.abs(segment))

        stft = torch.stft(
            segment,
            n_fft=N_FFT,
            hop_length=HOP_LENGTH,
            win_length=N_FFT,
            window=hann_window,
            return_complex=True,
            center=False
        )

        power_spectrum = stft.abs().pow(2)
        mel = torch.matmul(mel_filters, power_spectrum)
        mel_db = T.AmplitudeToDB()(mel)

        mel_spects.append(mel_db.cpu().numpy())

    return mel_spects

# %%
def run_inference(mel_spects):
    """
    Runs model inference on list of mel spectrograms.
    Prints time-stamped predictions.
    """
    results = defaultdict(list)

    for idx, mel in enumerate(mel_spects):
        mel_input = np.expand_dims(mel, axis=(0, -1)).astype(np.float32)

        time_sec = idx * STEP_SIZE
        timestamp = f"{int(time_sec // 60):01d}:{int(time_sec % 60):02d}"

        interpreter.set_tensor(input_details[0]['index'], mel_input)
        interpreter.invoke()
        output = interpreter.get_tensor(output_details[0]['index'])

        binary_output = (output > CLASS_THRESHOLDS).astype(np.int32)[0]

        prediction_strs = [
            f"\033[92m{name}\033[0m" if pred else name
            for name, pred in zip(INSTRUMENTS, binary_output)
        ]

        print(f"{timestamp} | " + " | ".join(prediction_strs))

# %%
mel_spects = generate_mel_spect_gpu(AUDIO_PATH)
run_inference(mel_spects)
# Out:
# 0:00 | Piano | Guitar | Bass | Strings | Drums
# 0:00 | Piano | Guitar | Bass | Strings | Drums
# 0:01 | Piano | Guitar | Bass | Strings | Drums
# 0:01 | Piano | Guitar | Bass | Strings | Drums
# 0:02 | Piano | Guitar | Bass | Strings | Drums
# 0:02 | Piano | Guitar | Bass | Strings | Drums
# 0:03 | Piano | Guitar | Bass | Strings | Drums
# 0:03 | Piano | Guitar | Bass | Strings | Drums
# 0:04 | Piano | Guitar | Bass | Strings | Drums
# 0:04 | Piano | Guitar | Bass | Strings | Drums
# 0:05 | Piano | Guitar | Bass | Strings | Drums
# 0:05 | Piano | Guitar | Bass | Strings | Drums
# 0:06 | Piano | Guitar | Bass | Strings | Drums
# 0:06 | Piano | Guitar | Bass | Strings | Drums
# 0:07 | Piano | Guitar | Bass | Strings | Drums
# 0:07 | Piano | Guitar | Bass | Strings | Drums
# 0:08 | Piano | Guitar | Bass | Strings | Drums
# 0:08 | Piano | Guitar | Bass | Strings | Drums
# 0:09 | Piano | Guitar | Bass | Strings | Drums
# 0:09 | Piano | Guitar | Bass | Strings | Drums
# 0:10 | Piano | Guitar | Bass | Strings | Drums
# 0:10 | Piano | Guitar | Bass | Strings | Drums
# 0:11 | Piano | Guitar | Bass | Strings | Drums
# 0:11 | Piano | Guitar | Bass | Strings | Drums
# 0:12 | Piano | Guitar | Bass | Strings | Drums
# 0:12 | Piano | Guitar | Bass | Strings | Drums
# 0:13 | Piano | Guitar | Bass | Strings | Drums
# 0:13 | Piano | Guitar | Bass | Strings | Drums
# 0:14 | Piano | Guitar | Bass | Strings | Drums
# 0:14 | Piano | Guitar | Bass | Strings | Drums
# 0:15 | Piano | Guitar | Bass | Strings | Drums
# 0:15 | Piano | Guitar | Bass | Strings | Drums
# 0:16 | Piano | Guitar | Bass | Strings | Drums
# 0:16 | Piano | Guitar | Bass | Strings | Drums
# 0:17 | Piano | Guitar | Bass | Strings | Drums
# 0:17 | Piano | Guitar | Bass | Strings | Drums
# 0:18 | Piano | Guitar | Bass | Strings | Drums
# 0:18 | Piano | Guitar | Bass | Strings | Drums
# 0:19 | Piano | Guitar | Bass | Strings | Drums
# 0:19 | Piano | Guitar | Bass | Strings | Drums
# 0:20 | Piano | Guitar | Bass | Strings | Drums
# 0:20 | Piano | Guitar | Bass | Strings | Drums
# 0:21 | Piano | Guitar | Bass | Strings | Drums
# 0:21 | Piano | Guitar | Bass | Strings | Drums
# 0:22 | Piano | Guitar | Bass | Strings | Drums
# 0:22 | Piano | Guitar | Bass | Strings | Drums
# 0:23 | Piano | Guitar | Bass | Strings | Drums
# 0:23 | Piano | Guitar | Bass | Strings | Drums
# 0:24 | Piano | Guitar | Bass | Strings | Drums
# 0:24 | Piano | Guitar | Bass | Strings | Drums
# 0:25 | Piano | Guitar | Bass | Strings | Drums
# 0:25 | Piano | Guitar | Bass | Strings | Drums
# 0:26 | Piano | Guitar | Bass | Strings | Drums
# 0:26 | Piano | Guitar | Bass | Strings | Drums
# 0:27 | Piano | Guitar | Bass | Strings | Drums
# 0:27 | Piano | Guitar | Bass | Strings | Drums
# 0:28 | Piano | Guitar | Bass | Strings | Drums
# 0:28 | Piano | Guitar | Bass | Strings | Drums
# 0:29 | Piano | Guitar | Bass | Strings | Drums
# 0:29 | Piano | Guitar | Bass | Strings | Drums
# 0:30 | Piano | Guitar | Bass | Strings | Drums
# 0:30 | Piano | Guitar | Bass | Strings | Drums
# 0:31 | Piano | Guitar | Bass | Strings | Drums
# 0:31 | Piano | Guitar | Bass | Strings | Drums
# 0:32 | Piano | Guitar | Bass | Strings | Drums
# 0:32 | Piano | Guitar | Bass | Strings | Drums
# 0:33 | Piano | Guitar | Bass | Strings | Drums
# 0:33 | Piano | Guitar | Bass | Strings | Drums
# 0:34 | Piano | Guitar | Bass | Strings | Drums
# 0:34 | Piano | Guitar | Bass | Strings | Drums
# 0:35 | Piano | Guitar | Bass | Strings | Drums
# 0:35 | Piano | Guitar | Bass | Strings | Drums
# 0:36 | Piano | Guitar | Bass | Strings | Drums
# 0:36 | Piano | Guitar | Bass | Strings | Drums
# 0:37 | Piano | Guitar | Bass | Strings | Drums
# 0:37 | Piano | Guitar | Bass | Strings | Drums
# 0:38 | Piano | Guitar | Bass | Strings | Drums
# 0:38 | Piano | Guitar | Bass | Strings | Drums
# 0:39 | Piano | Guitar | Bass | Strings | Drums
# 0:39 | Piano | Guitar | Bass | Strings | Drums
# 0:40 | Piano | Guitar | Bass | Strings | Drums
# 0:40 | Piano | Guitar | Bass | Strings | Drums
# 0:41 | Piano | Guitar | Bass | Strings | Drums
# 0:41 | Piano | Guitar | Bass | Strings | Drums
# 0:42 | Piano | Guitar | Bass | Strings | Drums
# 0:42 | Piano | Guitar | Bass | Strings | Drums
# 0:43 | Piano | Guitar | Bass | Strings | Drums
# 0:43 | Piano | Guitar | Bass | Strings | Drums
# 0:44 | Piano | Guitar | Bass | Strings | Drums
# 0:44 | Piano | Guitar | Bass | Strings | Drums
# 0:45 | Piano | Guitar | Bass | Strings | Drums
# 0:45 | Piano | Guitar | Bass | Strings | Drums
# 0:46 | Piano | Guitar | Bass | Strings | Drums
# 0:46 | Piano | Guitar | Bass | Strings | Drums
# 0:47 | Piano | Guitar | Bass | Strings | Drums
# 0:47 | Piano | Guitar | Bass | Strings | Drums
# 0:48 | Piano | Guitar | Bass | Strings | Drums
# 0:48 | Piano | Guitar | Bass | Strings | Drums
# 0:49 | Piano | Guitar | Bass | Strings | Drums
# 0:49 | Piano | Guitar | Bass | Strings | Drums
# 0:50 | Piano | Guitar | Bass | Strings | Drums
# 0:50 | Piano | Guitar | Bass | Strings | Drums
# 0:51 | Piano | Guitar | Bass | Strings | Drums
# 0:51 | Piano | Guitar | Bass | Strings | Drums
# 0:52 | Piano | Guitar | Bass | Strings | Drums
# 0:52 | Piano | Guitar | Bass | Strings | Drums
# 0:53 | Piano | Guitar | Bass | Strings | Drums
# 0:53 | Piano | Guitar | Bass | Strings | Drums
# 0:54 | Piano | Guitar | Bass | Strings | Drums
# 0:54 | Piano | Guitar | Bass | Strings | Drums
# 0:55 | Piano | Guitar | Bass | Strings | Drums
# 0:55 | Piano | Guitar | Bass | Strings | Drums
# 0:56 | Piano | Guitar | Bass | Strings | Drums
# 0:56 | Piano | Guitar | Bass | Strings | Drums
# 0:57 | Piano | Guitar | Bass | Strings | Drums
# 0:57 | Piano | Guitar | Bass | Strings | Drums
# 0:58 | Piano | Guitar | Bass | Strings | Drums
# 0:58 | Piano | Guitar | Bass | Strings | Drums
# 0:59 | Piano | Guitar | Bass | Strings | Drums
# 0:59 | Piano | Guitar | Bass | Strings | Drums
# 1:00 | Piano | Guitar | Bass | Strings | Drums
# 1:00 | Piano | Guitar | Bass | Strings | Drums
# 1:01 | Piano | Guitar | Bass | Strings | Drums
# 1:01 | Piano | Guitar | Bass | Strings | Drums
# 1:02 | Piano | Guitar | Bass | Strings | Drums
# 1:02 | Piano | Guitar | Bass | Strings | Drums
# 1:03 | Piano | Guitar | Bass | Strings | Drums
# 1:03 | Piano | Guitar | Bass | Strings | Drums
# 1:04 | Piano | Guitar | Bass | Strings | Drums
# 1:04 | Piano | Guitar | Bass | Strings | Drums
# 1:05 | Piano | Guitar | Bass | Strings | Drums
# 1:05 | Piano | Guitar | Bass | Strings | Drums
# 1:06 | Piano | Guitar | Bass | Strings | Drums
# 1:06 | Piano | Guitar | Bass | Strings | Drums
# 1:07 | Piano | Guitar | Bass | Strings | Drums
# 1:07 | Piano | Guitar | Bass | Strings | Drums
# 1:08 | Piano | Guitar | Bass | Strings | Drums
# 1:08 | Piano | Guitar | Bass | Strings | Drums
# 1:09 | Piano | Guitar | Bass | Strings | Drums
# 1:09 | Piano | Guitar | Bass | Strings | Drums
# 1:10 | Piano | Guitar | Bass | Strings | Drums
# 1:10 | Piano | Guitar | Bass | Strings | Drums
# 1:11 | Piano | Guitar | Bass | Strings | Drums
# 1:11 | Piano | Guitar | Bass | Strings | Drums
# 1:12 | Piano | Guitar | Bass | Strings | Drums
# 1:12 | Piano | Guitar | Bass | Strings | Drums
# 1:13 | Piano | Guitar | Bass | Strings | Drums
# 1:13 | Piano | Guitar | Bass | Strings | Drums
# 1:14 | Piano | Guitar | Bass | Strings | Drums
# 1:14 | Piano | Guitar | Bass | Strings | Drums
# 1:15 | Piano | Guitar | Bass | Strings | Drums
# 1:15 | Piano | Guitar | Bass | Strings | Drums
# 1:16 | Piano | Guitar | Bass | Strings | Drums
# 1:16 | Piano | Guitar | Bass | Strings | Drums
# 1:17 | Piano | Guitar | Bass | Strings | Drums
# 1:17 | Piano | Guitar | Bass | Strings | Drums
# 1:18 | Piano | Guitar | Bass | Strings | Drums
# 1:18 | Piano | Guitar | Bass | Strings | Drums
# 1:19 | Piano | Guitar | Bass | Strings | Drums
# 1:19 | Piano | Guitar | Bass | Strings | Drums
# 1:20 | Piano | Guitar | Bass | Strings | Drums
# 1:20 | Piano | Guitar | Bass | Strings | Drums
# 1:21 | Piano | Guitar | Bass | Strings | Drums
# 1:21 | Piano | Guitar | Bass | Strings | Drums
# 1:22 | Piano | Guitar | Bass | Strings | Drums
# 1:22 | Piano | Guitar | Bass | Strings | Drums
# 1:23 | Piano | Guitar | Bass | Strings | Drums
# 1:23 | Piano | Guitar | Bass | Strings | Drums
# 1:24 | Piano | Guitar | Bass | Strings | Drums
# 1:24 | Piano | Guitar | Bass | Strings | Drums
# 1:25 | Piano | Guitar | Bass | Strings | Drums
# 1:25 | Piano | Guitar | Bass | Strings | Drums
# 1:26 | Piano | Guitar | Bass | Strings | Drums
# 1:26 | Piano | Guitar | Bass | Strings | Drums
# 1:27 | Piano | Guitar | Bass | Strings | Drums
# 1:27 | Piano | Guitar | Bass | Strings | Drums
# 1:28 | Piano | Guitar | Bass | Strings | Drums
# 1:28 | Piano | Guitar | Bass | Strings | Drums
# 1:29 | Piano | Guitar | Bass | Strings | Drums
# 1:29 | Piano | Guitar | Bass | Strings | Drums
# 1:30 | Piano | Guitar | Bass | Strings | Drums
# 1:30 | Piano | Guitar | Bass | Strings | Drums
# 1:31 | Piano | Guitar | Bass | Strings | Drums
# 1:31 | Piano | Guitar | Bass | Strings | Drums
# 1:32 | Piano | Guitar | Bass | Strings | Drums
# 1:32 | Piano | Guitar | Bass | Strings | Drums
# 1:33 | Piano | Guitar | Bass | Strings | Drums
# 1:33 | Piano | Guitar | Bass | Strings | Drums
# 1:34 | Piano | Guitar | Bass | Strings | Drums
# 1:34 | Piano | Guitar | Bass | Strings | Drums
# 1:35 | Piano | Guitar | Bass | Strings | Drums
# 1:35 | Piano | Guitar | Bass | Strings | Drums
# 1:36 | Piano | Guitar | Bass | Strings | Drums
# 1:36 | Piano | Guitar | Bass | Strings | Drums
# 1:37 | Piano | Guitar | Bass | Strings | Drums
# 1:37 | Piano | Guitar | Bass | Strings | Drums
# 1:38 | Piano | Guitar | Bass | Strings | Drums
# 1:38 | Piano | Guitar | Bass | Strings | Drums
# 1:39 | Piano | Guitar | Bass | Strings | Drums
# 1:39 | Piano | Guitar | Bass | Strings | Drums
# 1:40 | Piano | Guitar | Bass | Strings | Drums
# 1:40 | Piano | Guitar | Bass | Strings | Drums
# 1:41 | Piano | Guitar | Bass | Strings | Drums
# 1:41 | Piano | Guitar | Bass | Strings | Drums
# 1:42 | Piano | Guitar | Bass | Strings | Drums
# 1:42 | Piano | Guitar | Bass | Strings | Drums
# 1:43 | Piano | Guitar | Bass | Strings | Drums
# 1:43 | Piano | Guitar | Bass | Strings | Drums
# 1:44 | Piano | Guitar | Bass | Strings | Drums
# 1:44 | Piano | Guitar | Bass | Strings | Drums
# 1:45 | Piano | Guitar | Bass | Strings | Drums
# 1:45 | Piano | Guitar | Bass | Strings | Drums
# 1:46 | Piano | Guitar | Bass | Strings | Drums
# 1:46 | Piano | Guitar | Bass | Strings | Drums
# 1:47 | Piano | Guitar | Bass | Strings | Drums
# 1:47 | Piano | Guitar | Bass | Strings | Drums
# 1:48 | Piano | Guitar | Bass | Strings | Drums
# 1:48 | Piano | Guitar | Bass | Strings | Drums
# 1:49 | Piano | Guitar | Bass | Strings | Drums
# 1:49 | Piano | Guitar | Bass | Strings | Drums
# 1:50 | Piano | Guitar | Bass | Strings | Drums
# 1:50 | Piano | Guitar | Bass | Strings | Drums
# 1:51 | Piano | Guitar | Bass | Strings | Drums
# 1:51 | Piano | Guitar | Bass | Strings | Drums
# 1:52 | Piano | Guitar | Bass | Strings | Drums
# 1:52 | Piano | Guitar | Bass | Strings | Drums
# 1:53 | Piano | Guitar | Bass | Strings | Drums
# 1:53 | Piano | Guitar | Bass | Strings | Drums
# 1:54 | Piano | Guitar | Bass | Strings | Drums
# 1:54 | Piano | Guitar | Bass | Strings | Drums
# 1:55 | Piano | Guitar | Bass | Strings | Drums
# 1:55 | Piano | Guitar | Bass | Strings | Drums
# 1:56 | Piano | Guitar | Bass | Strings | Drums
# 1:56 | Piano | Guitar | Bass | Strings | Drums
# 1:57 | Piano | Guitar | Bass | Strings | Drums
# 1:57 | Piano | Guitar | Bass | Strings | Drums
# 1:58 | Piano | Guitar | Bass | Strings | Drums
# 1:58 | Piano | Guitar | Bass | Strings | Drums
# 1:59 | Piano | Guitar | Bass | Strings | Drums
# 1:59 | Piano | Guitar | Bass | Strings | Drums
# 2:00 | Piano | Guitar | Bass | Strings | Drums
# 2:00 | Piano | Guitar | Bass | Strings | Drums
# 2:01 | Piano | Guitar | Bass | Strings | Drums
# 2:01 | Piano | Guitar | Bass | Strings | Drums
# 2:02 | Piano | Guitar | Bass | Strings | Drums
# 2:02 | Piano | Guitar | Bass | Strings | Drums
# 2:03 | Piano | Guitar | Bass | Strings | Drums
# 2:03 | Piano | Guitar | Bass | Strings | Drums
# 2:04 | Piano | Guitar | Bass | Strings | Drums
# 2:04 | Piano | Guitar | Bass | Strings | Drums
# 2:05 | Piano | Guitar | Bass | Strings | Drums
# 2:05 | Piano | Guitar | Bass | Strings | Drums
# 2:06 | Piano | Guitar | Bass | Strings | Drums
# 2:06 | Piano | Guitar | Bass | Strings | Drums
# 2:07 | Piano | Guitar | Bass | Strings | Drums
# 2:07 | Piano | Guitar | Bass | Strings | Drums
# 2:08 | Piano | Guitar | Bass | Strings | Drums
# 2:08 | Piano | Guitar | Bass | Strings | Drums
# 2:09 | Piano | Guitar | Bass | Strings | Drums
# 2:09 | Piano | Guitar | Bass | Strings | Drums
# 2:10 | Piano | Guitar | Bass | Strings | Drums
# 2:10 | Piano | Guitar | Bass | Strings | Drums
# 2:11 | Piano | Guitar | Bass | Strings | Drums
# 2:11 | Piano | Guitar | Bass | Strings | Drums
# 2:12 | Piano | Guitar | Bass | Strings | Drums
# 2:12 | Piano | Guitar | Bass | Strings | Drums
# 2:13 | Piano | Guitar | Bass | Strings | Drums
# 2:13 | Piano | Guitar | Bass | Strings | Drums
# 2:14 | Piano | Guitar | Bass | Strings | Drums
# 2:14 | Piano | Guitar | Bass | Strings | Drums
# 2:15 | Piano | Guitar | Bass | Strings | Drums
# 2:15 | Piano | Guitar | Bass | Strings | Drums
# 2:16 | Piano | Guitar | Bass | Strings | Drums
# 2:16 | Piano | Guitar | Bass | Strings | Drums
# 2:17 | Piano | Guitar | Bass | Strings | Drums
# 2:17 | Piano | Guitar | Bass | Strings | Drums
# 2:18 | Piano | Guitar | Bass | Strings | Drums
# 2:18 | Piano | Guitar | Bass | Strings | Drums
# 2:19 | Piano | Guitar | Bass | Strings | Drums
# 2:19 | Piano | Guitar | Bass | Strings | Drums
# 2:20 | Piano | Guitar | Bass | Strings | Drums
# 2:20 | Piano | Guitar | Bass | Strings | Drums
# 2:21 | Piano | Guitar | Bass | Strings | Drums
# 2:21 | Piano | Guitar | Bass | Strings | Drums
# 2:22 | Piano | Guitar | Bass | Strings | Drums
# 2:22 | Piano | Guitar | Bass | Strings | Drums
# 2:23 | Piano | Guitar | Bass | Strings | Drums
# 2:23 | Piano | Guitar | Bass | Strings | Drums
# 2:24 | Piano | Guitar | Bass | Strings | Drums
# 2:24 | Piano | Guitar | Bass | Strings | Drums
# 2:25 | Piano | Guitar | Bass | Strings | Drums
# 2:25 | Piano | Guitar | Bass | Strings | Drums
# 2:26 | Piano | Guitar | Bass | Strings | Drums
# 2:26 | Piano | Guitar | Bass | Strings | Drums
# 2:27 | Piano | Guitar | Bass | Strings | Drums
# 2:27 | Piano | Guitar | Bass | Strings | Drums
# 2:28 | Piano | Guitar | Bass | Strings | Drums
# 2:28 | Piano | Guitar | Bass | Strings | Drums
# 2:29 | Piano | Guitar | Bass | Strings | Drums
# 2:29 | Piano | Guitar | Bass | Strings | Drums
# 2:30 | Piano | Guitar | Bass | Strings | Drums
# 2:30 | Piano | Guitar | Bass | Strings | Drums
# 2:31 | Piano | Guitar | Bass | Strings | Drums
# 2:31 | Piano | Guitar | Bass | Strings | Drums
# 2:32 | Piano | Guitar | Bass | Strings | Drums
# 2:32 | Piano | Guitar | Bass | Strings | Drums
# 2:33 | Piano | Guitar | Bass | Strings | Drums
# 2:33 | Piano | Guitar | Bass | Strings | Drums
# 2:34 | Piano | Guitar | Bass | Strings | Drums
# 2:34 | Piano | Guitar | Bass | Strings | Drums
# 2:35 | Piano | Guitar | Bass | Strings | Drums
# 2:35 | Piano | Guitar | Bass | Strings | Drums
# 2:36 | Piano | Guitar | Bass | Strings | Drums
# 2:36 | Piano | Guitar | Bass | Strings | Drums
# 2:37 | Piano | Guitar | Bass | Strings | Drums
# 2:37 | Piano | Guitar | Bass | Strings | Drums
# 2:38 | Piano | Guitar | Bass | Strings | Drums
# 2:38 | Piano | Guitar | Bass | Strings | Drums
# 2:39 | Piano | Guitar | Bass | Strings | Drums
# 2:39 | Piano | Guitar | Bass | Strings | Drums
# 2:40 | Piano | Guitar | Bass | Strings | Drums
# 2:40 | Piano | Guitar | Bass | Strings | Drums
# 2:41 | Piano | Guitar | Bass | Strings | Drums
# 2:41 | Piano | Guitar | Bass | Strings | Drums
# 2:42 | Piano | Guitar | Bass | Strings | Drums
# 2:42 | Piano | Guitar | Bass | Strings | Drums
# 2:43 | Piano | Guitar | Bass | Strings | Drums
# 2:43 | Piano | Guitar | Bass | Strings | Drums
# 2:44 | Piano | Guitar | Bass | Strings | Drums
# 2:44 | Piano | Guitar | Bass | Strings | Drums
# 2:45 | Piano | Guitar | Bass | Strings | Drums
# 2:45 | Piano | Guitar | Bass | Strings | Drums
# 2:46 | Piano | Guitar | Bass | Strings | Drums
# 2:46 | Piano | Guitar | Bass | Strings | Drums
# 2:47 | Piano | Guitar | Bass | Strings | Drums
# 2:47 | Piano | Guitar | Bass | Strings | Drums
# 2:48 | Piano | Guitar | Bass | Strings | Drums
# 2:48 | Piano | Guitar | Bass | Strings | Drums
# 2:49 | Piano | Guitar | Bass | Strings | Drums
# 2:49 | Piano | Guitar | Bass | Strings | Drums
# 2:50 | Piano | Guitar | Bass | Strings | Drums
# 2:50 | Piano | Guitar | Bass | Strings | Drums
# 2:51 | Piano | Guitar | Bass | Strings | Drums
# 2:51 | Piano | Guitar | Bass | Strings | Drums
# 2:52 | Piano | Guitar | Bass | Strings | Drums
# 2:52 | Piano | Guitar | Bass | Strings | Drums
# 2:53 | Piano | Guitar | Bass | Strings | Drums
# 2:53 | Piano | Guitar | Bass | Strings | Drums
# 2:54 | Piano | Guitar | Bass | Strings | Drums
# 2:54 | Piano | Guitar | Bass | Strings | Drums
# 2:55 | Piano | Guitar | Bass | Strings | Drums
# 2:55 | Piano | Guitar | Bass | Strings | Drums
# 2:56 | Piano | Guitar | Bass | Strings | Drums
# 2:56 | Piano | Guitar | Bass | Strings | Drums
# 2:57 | Piano | Guitar | Bass | Strings | Drums
# 2:57 | Piano | Guitar | Bass | Strings | Drums
# 2:58 | Piano | Guitar | Bass | Strings | Drums
# 2:58 | Piano | Guitar | Bass | Strings | Drums
# 2:59 | Piano | Guitar | Bass | Strings | Drums
# 2:59 | Piano | Guitar | Bass | Strings | Drums
# 3:00 | Piano | Guitar | Bass | Strings | Drums
# 3:00 | Piano | Guitar | Bass | Strings | Drums
# 3:01 | Piano | Guitar | Bass | Strings | Drums
# 3:01 | Piano | Guitar | Bass | Strings | Drums
# 3:02 | Piano | Guitar | Bass | Strings | Drums
# 3:02 | Piano | Guitar | Bass | Strings | Drums
# 3:03 | Piano | Guitar | Bass | Strings | Drums
# 3:03 | Piano | Guitar | Bass | Strings | Drums
# 3:04 | Piano | Guitar | Bass | Strings | Drums
# 3:04 | Piano | Guitar | Bass | Strings | Drums
# 3:05 | Piano | Guitar | Bass | Strings | Drums
# 3:05 | Piano | Guitar | Bass | Strings | Drums
# 3:06 | Piano | Guitar | Bass | Strings | Drums
# 3:06 | Piano | Guitar | Bass | Strings | Drums
# 3:07 | Piano | Guitar | Bass | Strings | Drums
# 3:07 | Piano | Guitar | Bass | Strings | Drums
# 3:08 | Piano | Guitar | Bass | Strings | Drums
# 3:08 | Piano | Guitar | Bass | Strings | Drums
# 3:09 | Piano | Guitar | Bass | Strings | Drums
# 3:09 | Piano | Guitar | Bass | Strings | Drums
# 3:10 | Piano | Guitar | Bass | Strings | Drums
# 3:10 | Piano | Guitar | Bass | Strings | Drums
# 3:11 | Piano | Guitar | Bass | Strings | Drums
# 3:11 | Piano | Guitar | Bass | Strings | Drums
# 3:12 | Piano | Guitar | Bass | Strings | Drums
# 3:12 | Piano | Guitar | Bass | Strings | Drums
# 3:13 | Piano | Guitar | Bass | Strings | Drums
# 3:13 | Piano | Guitar | Bass | Strings | Drums
# 3:14 | Piano | Guitar | Bass | Strings | Drums
# 3:14 | Piano | Guitar | Bass | Strings | Drums
# 3:15 | Piano | Guitar | Bass | Strings | Drums
# 3:15 | Piano | Guitar | Bass | Strings | Drums
# 3:16 | Piano | Guitar | Bass | Strings | Drums
# 3:16 | Piano | Guitar | Bass | Strings | Drums
# 3:17 | Piano | Guitar | Bass | Strings | Drums
# 3:17 | Piano | Guitar | Bass | Strings | Drums
# 3:18 | Piano | Guitar | Bass | Strings | Drums
# 3:18 | Piano | Guitar | Bass | Strings | Drums
# 3:19 | Piano | Guitar | Bass | Strings | Drums
# 3:19 | Piano | Guitar | Bass | Strings | Drums
# 3:20 | Piano | Guitar | Bass | Strings | Drums
# 3:20 | Piano | Guitar | Bass | Strings | Drums
# 3:21 | Piano | Guitar | Bass | Strings | Drums
# 3:21 | Piano | Guitar | Bass | Strings | Drums
# 3:22 | Piano | Guitar | Bass | Strings | Drums
# 3:22 | Piano | Guitar | Bass | Strings | Drums
# 3:23 | Piano | Guitar | Bass | Strings | Drums
# 3:23 | Piano | Guitar | Bass | Strings | Drums
# 3:24 | Piano | Guitar | Bass | Strings | Drums
# 3:24 | Piano | Guitar | Bass | Strings | Drums
# 3:25 | Piano | Guitar | Bass | Strings | Drums
# 3:25 | Piano | Guitar | Bass | Strings | Drums
# 3:26 | Piano | Guitar | Bass | Strings | Drums
# 3:26 | Piano | Guitar | Bass | Strings | Drums
# 3:27 | Piano | Guitar | Bass | Strings | Drums
# 3:27 | Piano | Guitar | Bass | Strings | Drums
# 3:28 | Piano | Guitar | Bass | Strings | Drums
# 3:28 | Piano | Guitar | Bass | Strings | Drums
# 3:29 | Piano | Guitar | Bass | Strings | Drums
# 3:29 | Piano | Guitar | Bass | Strings | Drums
# 3:30 | Piano | Guitar | Bass | Strings | Drums
# 3:30 | Piano | Guitar | Bass | Strings | Drums
# 3:31 | Piano | Guitar | Bass | Strings | Drums
# 3:31 | Piano | Guitar | Bass | Strings | Drums
# 3:32 | Piano | Guitar | Bass | Strings | Drums
# 3:32 | Piano | Guitar | Bass | Strings | Drums
# 3:33 | Piano | Guitar | Bass | Strings | Drums
# 3:33 | Piano | Guitar | Bass | Strings | Drums
# 3:34 | Piano | Guitar | Bass | Strings | Drums
# 3:34 | Piano | Guitar | Bass | Strings | Drums
# 3:35 | Piano | Guitar | Bass | Strings | Drums
# 3:35 | Piano | Guitar | Bass | Strings | Drums
# 3:36 | Piano | Guitar | Bass | Strings | Drums
# 3:36 | Piano | Guitar | Bass | Strings | Drums
# 3:37 | Piano | Guitar | Bass | Strings | Drums
# 3:37 | Piano | Guitar | Bass | Strings | Drums
# 3:38 | Piano | Guitar | Bass | Strings | Drums
# 3:38 | Piano | Guitar | Bass | Strings | Drums
# 3:39 | Piano | Guitar | Bass | Strings | Drums
# 3:39 | Piano | Guitar | Bass | Strings | Drums
# 3:40 | Piano | Guitar | Bass | Strings | Drums
# 3:40 | Piano | Guitar | Bass | Strings | Drums
# 3:41 | Piano | Guitar | Bass | Strings | Drums
# 3:41 | Piano | Guitar | Bass | Strings | Drums
# 3:42 | Piano | Guitar | Bass | Strings | Drums
# 3:42 | Piano | Guitar | Bass | Strings | Drums
# 3:43 | Piano | Guitar | Bass | Strings | Drums
# 3:43 | Piano | Guitar | Bass | Strings | Drums
# 3:44 | Piano | Guitar | Bass | Strings | Drums
# 3:44 | Piano | Guitar | Bass | Strings | Drums
# 3:45 | Piano | Guitar | Bass | Strings | Drums
# 3:45 | Piano | Guitar | Bass | Strings | Drums
# 3:46 | Piano | Guitar | Bass | Strings | Drums
# 3:46 | Piano | Guitar | Bass | Strings | Drums
# 3:47 | Piano | Guitar | Bass | Strings | Drums
# 3:47 | Piano | Guitar | Bass | Strings | Drums
# 3:48 | Piano | Guitar | Bass | Strings | Drums
# 3:48 | Piano | Guitar | Bass | Strings | Drums
# 3:49 | Piano | Guitar | Bass | Strings | Drums
# 3:49 | Piano | Guitar | Bass | Strings | Drums
# 3:50 | Piano | Guitar | Bass | Strings | Drums
# 3:50 | Piano | Guitar | Bass | Strings | Drums
# 3:51 | Piano | Guitar | Bass | Strings | Drums
# 3:51 | Piano | Guitar | Bass | Strings | Drums
# 3:52 | Piano | Guitar | Bass | Strings | Drums
# 3:52 | Piano | Guitar | Bass | Strings | Drums
# 3:53 | Piano | Guitar | Bass | Strings | Drums
# 3:53 | Piano | Guitar | Bass | Strings | Drums
# 3:54 | Piano | Guitar | Bass | Strings | Drums
# 3:54 | Piano | Guitar | Bass | Strings | Drums
# 3:55 | Piano | Guitar | Bass | Strings | Drums
# 3:55 | Piano | Guitar | Bass | Strings | Drums
# 3:56 | Piano | Guitar | Bass | Strings | Drums
# 3:56 | Piano | Guitar | Bass | Strings | Drums
# 3:57 | Piano | Guitar | Bass | Strings | Drums
# 3:57 | Piano | Guitar | Bass | Strings | Drums
# 3:58 | Piano | Guitar | Bass | Strings | Drums
# 3:58 | Piano | Guitar | Bass | Strings | Drums
# 3:59 | Piano | Guitar | Bass | Strings | Drums
# 3:59 | Piano | Guitar | Bass | Strings | Drums
# 4:00 | Piano | Guitar | Bass | Strings | Drums
# 4:00 | Piano | Guitar | Bass | Strings | Drums
# 4:01 | Piano | Guitar | Bass | Strings | Drums
# 4:01 | Piano | Guitar | Bass | Strings | Drums
# 4:02 | Piano | Guitar | Bass | Strings | Drums
# 4:02 | Piano | Guitar | Bass | Strings | Drums
# 4:03 | Piano | Guitar | Bass | Strings | Drums
# 4:03 | Piano | Guitar | Bass | Strings | Drums
# 4:04 | Piano | Guitar | Bass | Strings | Drums
# 4:04 | Piano | Guitar | Bass | Strings | Drums
# 4:05 | Piano | Guitar | Bass | Strings | Drums
# 4:05 | Piano | Guitar | Bass | Strings | Drums
# 4:06 | Piano | Guitar | Bass | Strings | Drums
# 4:06 | Piano | Guitar | Bass | Strings | Drums
# 4:07 | Piano | Guitar | Bass | Strings | Drums
# 4:07 | Piano | Guitar | Bass | Strings | Drums
# 4:08 | Piano | Guitar | Bass | Strings | Drums
# 4:08 | Piano | Guitar | Bass | Strings | Drums
# 4:09 | Piano | Guitar | Bass | Strings | Drums
# 4:09 | Piano | Guitar | Bass | Strings | Drums
# 4:10 | Piano | Guitar | Bass | Strings | Drums
# 4:10 | Piano | Guitar | Bass | Strings | Drums
# 4:11 | Piano | Guitar | Bass | Strings | Drums
# 4:11 | Piano | Guitar | Bass | Strings | Drums
# 4:12 | Piano | Guitar | Bass | Strings | Drums
# 4:12 | Piano | Guitar | Bass | Strings | Drums
# 4:13 | Piano | Guitar | Bass | Strings | Drums
# 4:13 | Piano | Guitar | Bass | Strings | Drums
# 4:14 | Piano | Guitar | Bass | Strings | Drums
# 4:14 | Piano | Guitar | Bass | Strings | Drums
# 4:15 | Piano | Guitar | Bass | Strings | Drums
# 4:15 | Piano | Guitar | Bass | Strings | Drums
# 4:16 | Piano | Guitar | Bass | Strings | Drums
# 4:16 | Piano | Guitar | Bass | Strings | Drums
# 4:17 | Piano | Guitar | Bass | Strings | Drums
# 4:17 | Piano | Guitar | Bass | Strings | Drums
